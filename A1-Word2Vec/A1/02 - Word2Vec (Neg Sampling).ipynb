# %% [markdown]
# # Word2Vec (Negative Sampling)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import nltk
import torch.nn as nn
import torch.optim as optim
import matplotlib
import time
import nltk.corpus 
from nltk.corpus import brown

# %%
np.__version__, torch.__version__
# Out:
# ('2.3.5', '2.5.1+cu121')

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.8'

# %% [markdown]
# ## 1. Load data

# %%
# Load brown corpus (real-world data for final training)
nltk.download('brown')
nltk.download('punkt')
sentences = brown.sents(categories = "news")
sentences = [[word.lower() for word in sent] for sent in sentences]
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
corpus = []
sentences = brown.sents(categories="news")
corpus = [' '.join(sent).lower() for sent in sentences]

# %%
corpus[0][0]
# Out:
# 't'

# %%
#1. tokenization
corpus
corpus = [sent.split(" ") for sent in corpus]

# %%
#2. numeralization
#find unique words
flatten = lambda l: [item for sublist in l for item in sublist]
#assign unique integer
vocabs = list(set(flatten(corpus))) #all the words we have in the system - <UNK>

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocabs)}
print(word2index)
# Out:
# {'pennsylvania': 0, 'frustrations': 1, "flock's": 2, 'chandler': 3, 'precipitated': 4, 'eliminates': 5, 'ocean': 6, 'convenient': 7, 'zeising': 8, 'dapper': 9, 'sofas': 10, 'movement': 11, 'booklists': 12, 'constitutional': 13, 'educators': 14, 'destroy': 15, 'summerdale': 16, 'long-time': 17, 'transportation': 18, 'informal': 19, 'purpose': 20, 'correspondents': 21, 'malmud': 22, 'particulars': 23, 'roller': 24, 'surveys': 25, '80': 26, 'thereby': 27, 'knoll': 28, 'collonaded': 29, 'while': 30, 'federation': 31, 'implementation': 32, 'missiles': 33, 'beautifully': 34, 'squared': 35, '1,512': 36, 'coasted': 37, 'reporters': 38, 'treaty': 39, 'details': 40, 'moore': 41, 'brocade': 42, 'north': 43, 'balance': 44, 'barber': 45, 'second-place': 46, 'forming': 47, 'compiled': 48, 'strengthened': 49, 'leonard': 50, '2-baser': 51, 'spahnie': 52, "taxpayer's": 53, 'hoover': 54, 'reformatory': 55, 'sterling': 56, 'captured': 57, '70': 58, 'youths': 59, 'submarine-ball': 60, 'gen.': 61, 'karns': 62, '17-1/2-inch': 63, 'weigh': 64, 'tulsa': 65, 'future': 66, 'wholly-owned': 67, 'historian': 68, 'prosecutor': 69, 'genuine': 70, 'bass': 71, 'boston': 72, 'mont.': 73, 'peculiar': 74, 'salesman': 75, 'result': 76, 'fiercest': 77, 'hundred': 78, 'warnings': 79, 'plains': 80, 'hold-back': 81, 'latter': 82, 'fruitful': 83, 'scholastics': 84, 'themselves': 85, 'occupying': 86, 'shown': 87, 'tired': 88, 'seattle': 89, 'huntington': 90, 'notion': 91, 'commitment': 92, 'substantially': 93, 'temperament': 94, 'learned': 95, 'plate': 96, 'southerner': 97, 'exchange': 98, 'nickels': 99, 'proper': 100, 'evelyn': 101, 'claus': 102, 'robbins': 103, 'echoes': 104, 'watched': 105, '1933': 106, 'peace-loving': 107, 'fitted': 108, 'fallacious': 109, 'roberts': 110, '4:30': 111, 'puppet': 112, 'chaplin': 113, 'breed': 114, 'gather': 115, 'ablaze': 116, 'autumn': 117, "night's": 118, '2-1/2': 119, 'processing': 120, 'undergoing': 121, 'seven-iron': 122, 'feeling': 123, '2-3/4': 124, 'casualty': 125, 'congregation': 126, 'denied': 127, 'use': 128, 'spirit': 129, 'pennant': 130, 'bids': 131, 'hawing': 132, 'loewe': 133, "d'etat": 134, 'fairly': 135, "i'm": 136, 'design-conscious': 137, 'incidents': 138, 'fellows': 139, 'sitting': 140, '44-year-old': 141, 'red': 142, '6-foot': 143, 'authorities': 144, 'airplane': 145, 'quarterbacks': 146, 'alusik': 147, 'fresh': 148, '6': 149, 'growth': 150, 'purchased': 151, 'bookseller': 152, 'degree': 153, 'alterations': 154, 'microfilm': 155, 'stockholder': 156, 'primary': 157, 'in': 158, 'tickets': 159, 'dick': 160, 'amending': 161, 'incomparable': 162, 'startled': 163, 'installed': 164, 'lawford': 165, "capital's": 166, '5-day': 167, 'papers': 168, 'forces': 169, "mccloy's": 170, 'homeowners': 171, 'idols': 172, 'ballets': 173, 'self': 174, 'bryson': 175, 'teamsters': 176, 'picketed': 177, 'dignity': 178, 'rickards': 179, 'water': 180, 'note': 181, 'richard': 182, 'peoples': 183, 'maynor': 184, '1919': 185, 'e.': 186, 'treadwell': 187, 'perturbed': 188, 'tripled': 189, 'headmaster': 190, 'glamor': 191, 'mustang': 192, 'stalemate': 193, 'coal': 194, '175': 195, 'strayed': 196, 'labor-management': 197, 'tenure': 198, 'reconvention': 199, 'trends': 200, 'strenuous': 201, 'stupidity': 202, '1899': 203, 'every': 204, 'competition': 205, 'affirmation': 206, 'physician': 207, 'beaming': 208, 'ringside': 209, "warehouseman's": 210, 'chiang': 211, '1922': 212, 'resort': 213, 'stopovers': 214, 'nodded': 215, 'stimulant': 216, 'bertorelli': 217, 'frustrated': 218, 'shade': 219, 'soviet': 220, 'squarely': 221, 'outdoors': 222, '4-1/2%': 223, 'judge': 224, 'sharing': 225, 'questions': 226, 'pickers': 227, 'forcing': 228, 'revenuers': 229, 'moments': 230, 'paycheck': 231, 'improve': 232, 'double': 233, 'schley': 234, 'stanley': 235, 'waggin': 236, 'heinkel': 237, 'enthralled': 238, 'stevedore': 239, 'hill': 240, 'congressional': 241, 'banjo': 242, 'jet': 243, 'embezzlement': 244, 'wash': 245, 'january': 246, 'probate': 247, 'shoes': 248, ...

# %%
# Step 2: Tokenize brown corpus

tokenized_sentences = sentences

print("Number of tokenized sentences:", len(tokenized_sentences))
print("Sample tokenized sentence (first 30 words):")
print(tokenized_sentences[0][:30])


vocabs.append('<UNK>')
word2index['<UNK>'] = len(vocabs) - 1
# Out:
# Number of tokenized sentences: 4623
# Sample tokenized sentence (first 30 words):
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %%
word2index
# Out:
# {'pennsylvania': 0,
#  'frustrations': 1,
#  "flock's": 2,
#  'chandler': 3,
#  'precipitated': 4,
#  'eliminates': 5,
#  'ocean': 6,
#  'convenient': 7,
#  'zeising': 8,
#  'dapper': 9,
#  'sofas': 10,
#  'movement': 11,
#  'booklists': 12,
#  'constitutional': 13,
#  'educators': 14,
#  'destroy': 15,
#  'summerdale': 16,
#  'long-time': 17,
#  'transportation': 18,
#  'informal': 19,
#  'purpose': 20,
#  'correspondents': 21,
#  'malmud': 22,
#  'particulars': 23,
#  'roller': 24,
#  'surveys': 25,
#  '80': 26,
#  'thereby': 27,
#  'knoll': 28,
#  'collonaded': 29,
#  'while': 30,
#  'federation': 31,
#  'implementation': 32,
#  'missiles': 33,
#  'beautifully': 34,
#  'squared': 35,
#  '1,512': 36,
#  'coasted': 37,
#  'reporters': 38,
#  'treaty': 39,
#  'details': 40,
#  'moore': 41,
#  'brocade': 42,
#  'north': 43,
#  'balance': 44,
#  'barber': 45,
#  'second-place': 46,
#  'forming': 47,
#  'compiled': 48,
#  'strengthened': 49,
#  'leonard': 50,
#  '2-baser': 51,
#  'spahnie': 52,
#  "taxpayer's": 53,
#  'hoover': 54,
#  'reformatory': 55,
#  'sterling': 56,
#  'captured': 57,
#  '70': 58,
#  'youths': 59,
#  'submarine-ball': 60,
#  'gen.': 61,
#  'karns': 62,
#  '17-1/2-inch': 63,
#  'weigh': 64,
#  'tulsa': 65,
#  'future': 66,
#  'wholly-owned': 67,
#  'historian': 68,
#  'prosecutor': 69,
#  'genuine': 70,
#  'bass': 71,
#  'boston': 72,
#  'mont.': 73,
#  'peculiar': 74,
#  'salesman': 75,
#  'result': 76,
#  'fiercest': 77,
#  'hundred': 78,
#  'warnings': 79,
#  'plains': 80,
#  'hold-back': 81,
#  'latter': 82,
#  'fruitful': 83,
#  'scholastics': 84,
#  'themselves': 85,
#  'occupying': 86,
#  'shown': 87,
#  'tired': 88,
#  'seattle': 89,
#  'huntington': 90,
#  'notion': 91,
#  'commitment': 92,
#  'substantially': 93,
#  'temperament': 94,
#  'learned': 95,
#  'plate': 96,
#  'southerner': 97,
#  'exchange': 98,
#  'nickels': 99,
#  'proper': 100,
#  'evelyn': 101,
#  'claus': 102,
#  'robbins': 103,
#  'echoes': 104,
#  'watched': 105,
#  '1933': 106,
#  'peace-loving': 107,
#  'fitted': 108,
#  'fallacious': 109,
#  'roberts': 110,
#  '4:30': 111,
#  'puppet': 112,
#  'chaplin': 113,
#  'breed': 114,
#  'gather': 115,
#  'ablaze': 116,
#  'autumn': 117,
#  "night's": 118,
#  '2-1/2': 119,
#  'processing': 120,
#  'undergoing': 121,
#  'seven-iron': 122,
#  'feeling': 123,
#  '2-3/4': 124,
#  'casualty': 125,
#  'congregation': 126,
#  'denied': 127,
#  'use': 128,
#  'spirit': 129,
#  'pennant': 130,
#  'bids': 131,
#  'hawing': 132,
#  'loewe': 133,
#  "d'etat": 134,
#  'fairly': 135,
#  "i'm": 136,
#  'design-conscious': 137,
#  'incidents': 138,
#  'fellows': 139,
#  'sitting': 140,
#  '44-year-old': 141,
#  'red': 142,
#  '6-foot': 143,
#  'authorities': 144,
#  'airplane': 145,
#  'quarterbacks': 146,
#  'alusik': 147,
#  'fresh': 148,
#  '6': 149,
#  'growth': 150,
#  'purchased': 151,
#  'bookseller': 152,
#  'degree': 153,
#  'alterations': 154,
#  'microfilm': 155,
#  'stockholder': 156,
#  'primary': 157,
#  'in': 158,
#  'tickets': 159,
#  'dick': 160,
#  'amending': 161,
#  'incomparable': 162,
#  'startled': 163,
#  'installed': 164,
#  'lawford': 165,
#  "capital's": 166,
#  '5-day': 167,
#  'papers': 168,
#  'forces': 169,
#  "mccloy's": 170,
#  'homeowners': 171,
#  'idols': 172,
#  'ballets': 173,
#  'self': 174,
#  'bryson': 175,
#  'teamsters': 176,
#  'picketed': 177,
#  'dignity': 178,
#  'rickards': 179,
#  'water': 180,
#  'note': 181,
#  'richard': 182,
#  'peoples': 183,
#  'maynor': 184,
#  '1919': 185,
#  'e.': 186,
#  'treadwell': 187,
#  'perturbed': 188,
#  'tripled': 189,
#  'headmaster': 190,
#  'glamor': 191,
#  'mustang': 192,
#  'stalemate': 193,
#  'coal': 194,
#  '175': 195,
#  'strayed': 196,
#  'labor-management': 197,
#  'tenure': 198,
#  'reconvention': 199,
#  'trends': 200,
#  'strenuous': 201,
#  'stupidity': 202,
#  '1899': 203,
#  'every': 204,
#  'competition': 205,
#  'affirmation': 206,
#  'physician': 207,
#  'beaming': 208,
#  'ringside': 209,
#  "warehouseman's": 210,
#  'chiang': 211,
#  '1922': 212,
#  'resort': 213,
#  'stopovers': 214,
#  'nodded': 215,
#  'stimulant': 216,
#  'bertorelli': 217,
#  'frustrated': 218,
#  'shade': 219,
#  'soviet': 220,
#  'squarely': 221,
#  'outdoors': 222,
#  '4-1/2%': 223,
#  'judge': 224,
#  'sharing': 225,
#  'questions': 226,
#  'pickers': 227,
#  'forcing': 228,
#  'revenuers': 229,
#  'moments': 230,
#  'paycheck': 231,
#  'improve': 232,
#  'double': 233,
#  'schley': 234,
#  'stanley': 235,
#  'waggin': 236,
#  'heinkel': 237,
#  'enthralled': 238,
#  'stevedore': 239,
#  'hill': 240,
#  'congressional': 241,
#  'banjo': 242,
#  'jet': 243,
#  'embezzlement': 244,
#  'wash': 245,
#  'january': 246,
#  'probate': 247,
#  'shoes': 248,
#  'brownings': 249,
#  'were': 250,
#  'c': 251,
#  'presidential': 252,
#  '$37': 253,
#  'franchise': 254,
#  'signals': 255,
#  "students'": 256,
#  'dish': 257,
#  'unmeritorious': 258,
#  'darrow': 259,
#  'propelling': 260,
#  'oppose': 261,
#  'forecasts': 262,
#  'profili': 263,
#  'describing': 264,
#  'efficient': 265,
#  'further': 266,
#  'dazzler': 267,
#  '69': 268,
#  'noel': 269,
#  'pleasant': 270,
#  'pertained': 271,
#  'completion': 272,
#  'main': 273,
#  'gradually': 274,
#  'protect': 275,
#  '$18.2': 276,
#  'blumenthal': 277,
#  'dennis': 278,
#  'walnut': 279,
#  'g.': 280,
#  '13-5': 281,
#  'kimmell': 282,
#  'democratic-endorsed': 283,
#  'marine': 284,
#  'france': 285,
#  'packs': 286,
#  'greater': 287,
#  'trimmed': 288,
#  'fierce': 289,
#  'kern': 290,
#  'spraying': 291,
#  'ultimate': 292,
#  '5835': 293,
#  'experiencing': 294,
#  'pictured': 295,
#  'numerous': 296,
#  'administered': 297,
#  '1960s': 298,
#  'distinguished': 299,
#  '1910-14': 300,
#  'loop': 301,
#  'does': 302,
#  'author': 303,
#  'gas': 304,
#  "coach's": 305,
#  'grayson': 306,
#  'stitch': 307,
#  'authorize': 308,
#  '200': 309,
#  'glass': 310,
#  'relatively': 311,
#  'rayburn': 312,
#  '1959': 313,
#  'banned': 314,
#  'lettered': 315,
#  'consultant': 316,
#  'genevieve': 317,
#  'hired': 318,
#  'eustis': 319,
#  'east': 320,
#  'confrontation': 321,
#  'tex.': 322,
#  'missed': 323,
#  '2269': 324,
#  '1940': 325,
#  'opposite': 326,
#  "contractor's": 327,
#  'posed': 328,
#  'adair': 329,
#  'braves': 330,
#  'appliances': 331,
#  'towering': 332,
#  'derived': 333,
#  'here': 334,
#  'nuns': 335,
#  'imagines': 336,
#  'substance': 337,
#  'uniformed': 338,
#  '65%': 339,
#  'stages': 340,
#  'deteriorating': 341,
#  '121': 342,
#  'education': 343,
#  'therefore': 344,
#  'crews': 345,
#  '.': 346,
#  'during': 347,
#  'infant': 348,
#  'appreciation': 349,
#  'developments': 350,
#  'deal': 351,
#  'arm': 352,
#  'brother-in-law': 353,
#  'planners': 354,
#  'smallwood': 355,
#  'workers': 356,
#  'foreign': 357,
#  'ex-mrs.': 358,
#  '798': 359,
#  'worsens': 360,
#  'distinctly': 361,
#  'heralded': 362,
#  'lasted': 363,
#  'publicity': 364,
#  'compassionate': 365,
#  'suggested': 366,
#  'larceny': 367,
#  'bounds': 368,
#  'provides': 369,
#  'scrambled': 370,
#  'd.c.': 371,
#  'dead': 372,
#  'kanin': 373,
#  'fourth-down': 374,
#  '$100,000': 375,
#  'seize': 376,
#  'buchheister': 377,
#  'nick': 378,
#  'ponies': 379,
#  'dec.': 380,
#  'south': 381,
#  "junior's": 382,
#  'dealing': 383,
#  "engineers'": 384,
#  'carson': 385,
#  'sandra': 386,
#  'ratification': 387,
#  'miscount': 388,
#  'island': 389,
#  'staffed': 390,
#  'hearty': 391,
#  'dependence': 392,
#  '1688': 393,
#  'process': 394,
#  'replies': 395,
#  'dominated': 396,
#  'beaten': 397,
#  'greenwood': 398,
#  'upheld': 399,
#  "fardulli's": 400,
#  'flag-stick': 401,
#  'tech.': 402,
#  'threats': 403,
#  '1952': 404,
#  'lumumba': 405,
#  'underdeveloped': 406,
#  'particular': 407,
#  'sculptured': 408,
#  'recommendations': 409,
#  'puddingstone': 410,
#  'low-flying': 411,
#  'erred': 412,
#  'identically': 413,
#  'spending': 414,
#  'stoppages': 415,
#  'pad': 416,
#  'acclimatized': 417,
#  'culpas': 418,
#  'hard': 419,
#  'crypt': 420,
#  'rapped': 421,
#  'statistical': 422,
#  'scherer': 423,
#  'granular-type': 424,
#  'treated': 425,
#  'relations': 426,
#  'orleans': 427,
#  'seconds': 428,
#  'succeeding': 429,
#  'nuttall': 430,
#  'cooke': 431,
#  'bootle': 432,
#  'goods': 433,
#  'bludgeon': 434,
#  'egerton': 435,
#  'downtown': 436,
#  'urban': 437,
#  'aims': 438,
#  'salem': 439,
#  'squabbles': 440,
#  'nations': 441,
#  "manufacturers'": 442,
#  'scene': 443,
#  'fuels': 444,
#  'lyle': 445,
#  'practices': 446,
#  'paid-for': 447,
#  'okla.': 448,
#  'loading': 449,
#  'upi': 450,
#  '$1,600': 451,
#  'landscaped': 452,
#  'ligget': 453,
#  'big-league': 454,
#  'holabird': 455,
#  'adult': 456,
#  'critic': 457,
#  'passed': 458,
#  'closer': 459,
#  'dorsey': 460,
#  'slackening': 461,
#  'vernor': 462,
#  'you': 463,
#  'went': 464,
#  'anderlini': 465,
#  'struggles': 466,
#  'zinman': 467,
#  'competitive': 468,
#  'there': 469,
#  'yardstick': 470,
#  'establishing': 471,
#  'recalls': 472,
#  'opportunity': 473,
#  "chronicle's": 474,
#  'moffett': 475,
#  'canvassed': 476,
#  'surprise': 477,
#  '$457,000': 478,
#  '3-10': 479,
#  'socks': 480,
#  'joints': 481,
#  'inlaid': 482,
#  'stern': 483,
#  'balenciaga': 484,
#  'gave': 485,
#  '1957': 486,
#  'collided': 487,
#  'trigg': 488,
#  'envision': 489,
#  'gesture': 490,
#  "republicans'": 491,
#  'underwriting': 492,
#  'lull': 493,
#  'chance': 494,
#  'swearing': 495,
#  'okinawa': 496,
#  'encouraging': 497,
#  'capabilities': 498,
#  'aquinas': 499,
#  'gaynor': 500,
#  'underwater': 501,
#  'exports': 502,
#  'profit': 503,
#  'safety': 504,
#  'unquestionably': 505,
#  'pointed': 506,
#  'literature': 507,
#  'liberals': 508,
#  'stoll': 509,
#  'ghastly': 510,
#  'undergone': 511,
#  'poured': 512,
#  'staggered': 513,
#  '$1,500,000': 514,
#  'deemed': 515,
#  'vietnamese': 516,
#  'madame': 517,
#  'unlike': 518,
#  'hits': 519,
#  'ninety-nine': 520,
#  'accommodated': 521,
#  'sponsoring': 522,
#  'opening': 523,
#  'extend': 524,
#  'lavishly': 525,
#  'nowhere': 526,
#  'risk': 527,
#  'guatemala': 528,
#  'accurate': 529,
#  'drive-in': 530,
#  'idealist': 531,
#  'u.s.': 532,
#  'power': 533,
#  'switching': 534,
#  'slaughter': 535,
#  'mazeroski': 536,
#  'savannah': 537,
#  'employ': 538,
#  'handicapped': 539,
#  'pastime': 540,
#  'latch': 541,
#  'ideal': 542,
#  'three-day': 543,
#  'within': 544,
#  'impossibly': 545,
#  'wheat': 546,
#  'fastest': 547,
#  'run': 548,
#  '1937': 549,
#  'big': 550,
#  'mcn.': 551,
#  'violating': 552,
#  '237%': 553,
#  'bedrooms': 554,
#  'electricity': 555,
#  'dorenzo': 556,
#  'farrell': 557,
#  'discharge': 558,
#  'appealing': 559,
#  'onetime': 560,
#  'niece': 561,
#  'swearing-in': 562,
#  'crossing': 563,
#  'courbet': 564,
#  'remark': 565,
#  '20,000': 566,
#  "nation's": 567,
#  'music': 568,
#  'grace': 569,
#  '187.5': 570,
#  'parker': 571,
#  'unhappy': 572,
#  'retirements': 573,
#  'knows': 574,
#  '49ers': 575,
#  'grandparents': 576,
#  'recounting': 577,
#  '$253,355,000': 578,
#  'drizzly': 579,
#  "palmer's": 580,
#  'been': 581,
#  'pace': 582,
#  'better': 583,
#  'criminals': 584,
#  'oliver': 585,
#  '$80,738': 586,
#  'collection': 587,
#  'smashed': 588,
#  'arnold': 589,
#  'hardy': 590,
#  'wear': 591,
#  'expensive': 592,
#  'religious': 593,
#  'requirement': 594,
#  'voted': 595,
#  'preview': 596,
#  'instrument': 597,
#  'underprivileged': 598,
#  'violent': 599,
#  'heroin': 600,
#  'underlying': 601,
#  'ham': 602,
#  'disable': 603,
#  'candor': 604,
#  'dist.': 605,
#  'esprit': 606,
#  'visits': 607,
#  'r.l.': 608,
#  'sledding': 609,
#  'sugar': 610,
#  'side': 611,
#  'kroger': 612,
#  'philosopher': 613,
#  'three-hour': 614,
#  'typewriters': 615,
#  'advances': 616,
#  'brigantine': 617,
#  'forms': 618,
#  'researchers': 619,
#  'well-armed': 620,
#  'representations': 621,
#  'fatal': 622,
#  'faculty': 623,
#  '$8.50': 624,
#  'divided': 625,
#  'flowed': 626,
#  'pile': 627,
#  'washed-out': 628,
#  'moves': 629,
#  'parks': 630,
#  'tractor': 631,
#  'toughness': 632,
#  'forthcoming': 633,
#  'almost': 634,
#  'repertory': 635,
#  'planner': 636,
#  'send': 637,
#  'motto': 638,
#  'erection': 639,
#  'crime': 640,
#  'crackpots': 641,
#  '3-inch': 642,
#  'p.m.': 643,
#  'vitally': 644,
#  'craig': 645,
#  'penalized': 646,
#  'spokesman': 647,
#  'forty-year': 648,
#  'sixth-sense': 649,
#  'cincinnati': 650,
#  'givers': 651,
#  'couve': 652,
#  'plan': 653,
#  'staffs': 654,
#  'flower': 655,
#  'laotian': 656,
#  'dewey': 657,
#  'real': 658,
#  'bester': 659,
#  'bean': 660,
#  'nearby': 661,
#  'over-night': 662,
#  'acid': 663,
#  'sparkle': 664,
#  'master': 665,
#  'southwest': 666,
#  'three-building': 667,
#  'adcock': 668,
#  "league's": 669,
#  '4:18': 670,
#  'georgia-pacific': 671,
#  'bring': 672,
#  'a.a.u.': 673,
#  'disposal': 674,
#  'saute': 675,
#  'mink': 676,
#  'book-selection': 677,
#  'possessive': 678,
#  '2.5%': 679,
#  'reiterate': 680,
#  'lived': 681,
#  'release': 682,
#  'high-density': 683,
#  'shaw': 684,
#  'one-week-old': 685,
#  'talents': 686,
#  'rackmil': 687,
#  'complaining': 688,
#  'surgery': 689,
#  'hostages': 690,
#  'switch': 691,
#  'go': 692,
#  'unchecked': 693,
#  'allison': 694,
#  'thoroughfare': 695,
#  'ten-hour': 696,
#  '361': 697,
#  'thru': 698,
#  'us': 699,
#  'capitalist': 700,
#  'oxford': 701,
#  'modernized': 702,
#  'traveler': 703,
#  'truman': 704,
#  'overpowered': 705,
#  'smythe': 706,
#  'commerce': 707,
#  'edwards': 708,
#  'indictment': 709,
#  'orchids': 710,
#  'uncas': 711,
#  'firing': 712,
#  'clifford': 713,
#  "a's": 714,
#  'severly': 715,
#  'stark': 716,
#  'votes': 717,
#  'willingness': 718,
#  'trouble': 719,
#  'eddie': 720,
#  'walkout': 721,
#  'raymondville': 722,
#  'scarcely': 723,
#  'working': 724,
#  'factor': 725,
#  'warned': 726,
#  'negotiations': 727,
#  'bernie': 728,
#  'exhibited': 729,
#  'walter': 730,
#  'lace': 731,
#  'dignitaries': 732,
#  'president-elect': 733,
#  'tolls': 734,
#  'hollander': 735,
#  'crucified': 736,
#  'affect': 737,
#  'chico': 738,
#  'elements': 739,
#  'majorities': 740,
#  'pressed-paper': 741,
#  'politely': 742,
#  'detonation': 743,
#  'fergeson': 744,
#  "mills's": 745,
#  'fouled': 746,
#  'bernardine': 747,
#  '100%': 748,
#  'geography': 749,
#  'loaded': 750,
#  'buck': 751,
#  'embedded': 752,
#  'raising': 753,
#  'crashed': 754,
#  'climbed': 755,
#  'contracts': 756,
#  'suit': 757,
#  'arkansas': 758,
#  'wissahickon': 759,
#  '1865': 760,
#  'me': 761,
#  'wholesale': 762,
#  'fabrics': 763,
#  '55': 764,
#  'studying': 765,
#  'vieth': 766,
#  '5847': 767,
#  'tense': 768,
#  'alba': 769,
#  'leary': 770,
#  'undoubtedly': 771,
#  'high-school': 772,
#  'socialized': 773,
#  'join': 774,
#  'industrial': 775,
#  'undertakes': 776,
#  'deposit': 777,
#  'southwestern': 778,
#  'pro-western': 779,
#  'andrew': 780,
#  'communications': 781,
#  'whee': 782,
#  'relationships': 783,
#  'very': 784,
#  'bachelor': 785,
#  'globe-democrat': 786,
#  'crucial': 787,
#  'conversation': 788,
#  'consulate': 789,
#  'only': 790,
#  'we': 791,
#  'carruthers': 792,
#  'bed-time': 793,
#  'technicians': 794,
#  'vehicle': 795,
#  'due': 796,
#  'prominently': 797,
#  'unique': 798,
#  'initiating': 799,
#  'object': 800,
#  '33-man': 801,
#  'skid': 802,
#  'sybert': 803,
#  'tareytown': 804,
#  'priced': 805,
#  'champion': 806,
#  'waters': 807,
#  'gain': 808,
#  'wise': 809,
#  'mayor-nominate': 810,
#  'comprise': 811,
#  'hubert': 812,
#  'jolly': 813,
#  '300,000': 814,
#  'robertsons': 815,
#  'angeles': 816,
#  'companionship': 817,
#  'contact': 818,
#  'sylvania': 819,
#  'hills': 820,
#  'electrical': 821,
#  'plenty': 822,
#  'southerners': 823,
#  'cd': 824,
#  'cyclical': 825,
#  'instrumentals': 826,
#  'notably': 827,
#  'dental': 828,
#  'referendum': 829,
#  'recipients': 830,
#  'superior': 831,
#  "chicago's": 832,
#  'fireside': 833,
#  'churchmen': 834,
#  'princess': 835,
#  'marked': 836,
#  'gals': 837,
#  'joey': 838,
#  'abuse': 839,
#  'gotham': 840,
#  'purchase': 841,
#  'border': 842,
#  'pitcher': 843,
#  'idol': 844,
#  'danger': 845,
#  'woodcarver': 846,
#  'destroyer': 847,
#  'hudson': 848,
#  'governs': 849,
#  'solicitor': 850,
#  'skiddy': 851,
#  'groove': 852,
#  'conversion': 853,
#  'percentage': 854,
#  'slower': 855,
#  'sees': 856,
#  'friends': 857,
#  'jerry': 858,
#  '380-foot': 859,
#  'awareness': 860,
#  'slow': 861,
#  'revealed': 862,
#  'respond': 863,
#  'airport': 864,
#  '87th': 865,
#  'prix': 866,
#  'inferior': 867,
#  'sportswriter': 868,
#  '50,000,000': 869,
#  "monday's": 870,
#  '1213': 871,
#  'tractors': 872,
#  '3-month': 873,
#  'attempt': 874,
#  'congolese': 875,
#  'bum': 876,
#  'bexar': 877,
#  'ineffectual': 878,
#  'equipment': 879,
#  'computers': 880,
#  'convicted': 881,
#  'butlers': 882,
#  'frankie': 883,
#  'fulton': 884,
#  'foreman': 885,
#  'fourteen-nation': 886,
#  'scholar': 887,
#  'hong': 888,
#  'tosses': 889,
#  'bit': 890,
#  'harry': 891,
#  'verify': 892,
#  'characteristic': 893,
#  'led': 894,
#  'transit': 895,
#  'simultaneous': 896,
#  'eve': 897,
#  'rates': 898,
#  'micro-microcurie': 899,
#  'miniver': 900,
#  'fairy': 901,
#  'pastors': 902,
#  'resident': 903,
#  'realistic': 904,
#  '3300': 905,
#  'compacts': 906,
#  'chardon': 907,
#  'jean': 908,
#  'regents': 909,
#  'playable': 910,
#  "women's": 911,
#  '$37,500': 912,
#  'peaks': 913,
#  "rickey's": 914,
#  'positive': 915,
#  'yuri': 916,
#  '$28,700,000': 917,
#  'judges': 918,
#  'retrenching': 919,
#  'adventures': 920,
#  'plague': 921,
#  'costumes': 922,
#  '(': 923,
#  'wegener': 924,
#  'insects': 925,
#  'hyde': 926,
#  'abel': 927,
#  'knight': 928,
#  'unemployment': 929,
#  'vroman': 930,
#  'neveh': 931,
#  'oceania': 932,
#  'effectively': 933,
#  "speaker's": 934,
#  'begins': 935,
#  '20%': 936,
#  'ladies': 937,
#  'agents': 938,
#  '65': 939,
#  'honorary': 940,
#  'absorb': 941,
#  'starter': 942,
#  'cal.': 943,
#  'swipe': 944,
#  'engage': 945,
#  'publicly': 946,
#  'communism': 947,
#  'budgets': 948,
#  'scoring': 949,
#  'neighbor': 950,
#  'sokol': 951,
#  'enforcement': 952,
#  'warden': 953,
#  'newport': 954,
#  'vicinity': 955,
#  'constitution': 956,
#  'veteran': 957,
#  'something': 958,
#  'pun': 959,
#  'lisle': 960,
#  "mechanic's": 961,
#  'tuesday': 962,
#  "nato's": 963,
#  'enabled': 964,
#  'mentioned': 965,
#  'houghton': 966,
#  'blanche': 967,
#  'privilege': 968,
#  'path': 969,
#  'stockholders': 970,
#  'eventual': 971,
#  'virtues': 972,
#  'interference': 973,
#  'courageous': 974,
#  'parents': 975,
#  'bloodstream': 976,
#  'sleeps': 977,
#  'licensing': 978,
#  'imbroglio': 979,
#  'emerges': 980,
#  'idealism': 981,
#  'pursued': 982,
#  "glimco's": 983,
#  'german': 984,
#  '7': 985,
#  'reputedly': 986,
#  '59': 987,
#  "mayor's": 988,
#  'suffered': 989,
#  'chapelles': 990,
#  'church-state': 991,
#  'amicable': 992,
#  'holiday': 993,
#  'ex-singer': 994,
#  'executive': 995,
#  'so-far': 996,
#  'dimaggio': 997,
#  'hayward': 998,
#  'coordination': 999,
#  ...}

# %%
def generate_context(sentence, center_idx, window_size=2):
    """
    Generate context words for a given center word index using a dynamic window size.
    """
    start = max(0, center_idx - window_size)
    end = min(len(sentence), center_idx + window_size + 1)
    return [sentence[j] for j in range(start, end) if j != center_idx]


def generate_skipgram_pairs(sentences, window_size=2):
    """
    Generate (center, context) pairs for Skip-gram training.
    """
    pairs = []
    for sentence in sentences:
        for i, center in enumerate(sentence):
            context_words = generate_context(sentence, i, window_size)
            for context in context_words:
                pairs.append((center, context))
    return pairs


# Default window size
window_size = 2

# Generate Skip-gram training pairs
pairs = generate_skipgram_pairs(tokenized_sentences, window_size)
print("Number of (center, context) pairs generated:", len(pairs))
print("Sample (center, context) pairs:", pairs[:10])

# index2word = {v:k for k, v in word2index.items()}
# index2word[5]
# Out:
# Number of (center, context) pairs generated: 374548
# Sample (center, context) pairs: [('The', 'Fulton'), ('The', 'County'), ('Fulton', 'The'), ('Fulton', 'County'), ('Fulton', 'Grand'), ('County', 'The'), ('County', 'Fulton'), ('County', 'Grand'), ('County', 'Jury'), ('Grand', 'Fulton')]

# %%
corpus = flatten(corpus)

# %% [markdown]
# ## 2. Prepare train data

# %%
#create pairs of center word, and outside word

def random_batch(batch_size, corpus, window_size=2):
    if window_size < 1:
        raise ValueError("window_size must be >= 1")

    corpus_len = len(corpus)
    if corpus_len <= 2 * window_size:
        raise ValueError("corpus too small for given window_size")

    # valid center indices that have full window on both sides
    low = window_size
    high = corpus_len - window_size

    centers = np.random.randint(low, high, size=batch_size)
    inputs, labels = [], []

    for i in centers:
        center_word = corpus[i]
        # choose a random outside within the window (excluding center)
        offsets = list(range(-window_size, 0)) + list(range(1, window_size + 1))
        offset = np.random.choice(offsets)
        outside_word = corpus[i + offset]

        c_idx = word2index.get(center_word, word2index['<UNK>'])
        o_idx = word2index.get(outside_word, word2index['<UNK>'])

        inputs.append([c_idx])
        labels.append([o_idx])

    return np.array(inputs, dtype=np.int64), np.array(labels, dtype=np.int64)
            
x, y = random_batch(2, corpus)

# %%
x.shape  #batch_size, 1
# Out:
# (2, 1)

# %%
x
# Out:
# array([[11653],
#        [ 4959]])

# %%
y.shape  #batch_size 1
# Out:
# (2, 1)

# %% [markdown]
# ## 3. Negative Sampling
#
# ### Unigram distribution
#
# $$P(w)=U(w)^{3/4}/Z$$

# %%
z = 0.001

# %%
#count
from collections import Counter

word_count = Counter(corpus)
word_count

#get the total number of words
num_total_words = sum([c for w, c in word_count.items()])
num_total_words
# Out:
# 100554

# %%
vocabs
# Out:
# ['pennsylvania',
#  'frustrations',
#  "flock's",
#  'chandler',
#  'precipitated',
#  'eliminates',
#  'ocean',
#  'convenient',
#  'zeising',
#  'dapper',
#  'sofas',
#  'movement',
#  'booklists',
#  'constitutional',
#  'educators',
#  'destroy',
#  'summerdale',
#  'long-time',
#  'transportation',
#  'informal',
#  'purpose',
#  'correspondents',
#  'malmud',
#  'particulars',
#  'roller',
#  'surveys',
#  '80',
#  'thereby',
#  'knoll',
#  'collonaded',
#  'while',
#  'federation',
#  'implementation',
#  'missiles',
#  'beautifully',
#  'squared',
#  '1,512',
#  'coasted',
#  'reporters',
#  'treaty',
#  'details',
#  'moore',
#  'brocade',
#  'north',
#  'balance',
#  'barber',
#  'second-place',
#  'forming',
#  'compiled',
#  'strengthened',
#  'leonard',
#  '2-baser',
#  'spahnie',
#  "taxpayer's",
#  'hoover',
#  'reformatory',
#  'sterling',
#  'captured',
#  '70',
#  'youths',
#  'submarine-ball',
#  'gen.',
#  'karns',
#  '17-1/2-inch',
#  'weigh',
#  'tulsa',
#  'future',
#  'wholly-owned',
#  'historian',
#  'prosecutor',
#  'genuine',
#  'bass',
#  'boston',
#  'mont.',
#  'peculiar',
#  'salesman',
#  'result',
#  'fiercest',
#  'hundred',
#  'warnings',
#  'plains',
#  'hold-back',
#  'latter',
#  'fruitful',
#  'scholastics',
#  'themselves',
#  'occupying',
#  'shown',
#  'tired',
#  'seattle',
#  'huntington',
#  'notion',
#  'commitment',
#  'substantially',
#  'temperament',
#  'learned',
#  'plate',
#  'southerner',
#  'exchange',
#  'nickels',
#  'proper',
#  'evelyn',
#  'claus',
#  'robbins',
#  'echoes',
#  'watched',
#  '1933',
#  'peace-loving',
#  'fitted',
#  'fallacious',
#  'roberts',
#  '4:30',
#  'puppet',
#  'chaplin',
#  'breed',
#  'gather',
#  'ablaze',
#  'autumn',
#  "night's",
#  '2-1/2',
#  'processing',
#  'undergoing',
#  'seven-iron',
#  'feeling',
#  '2-3/4',
#  'casualty',
#  'congregation',
#  'denied',
#  'use',
#  'spirit',
#  'pennant',
#  'bids',
#  'hawing',
#  'loewe',
#  "d'etat",
#  'fairly',
#  "i'm",
#  'design-conscious',
#  'incidents',
#  'fellows',
#  'sitting',
#  '44-year-old',
#  'red',
#  '6-foot',
#  'authorities',
#  'airplane',
#  'quarterbacks',
#  'alusik',
#  'fresh',
#  '6',
#  'growth',
#  'purchased',
#  'bookseller',
#  'degree',
#  'alterations',
#  'microfilm',
#  'stockholder',
#  'primary',
#  'in',
#  'tickets',
#  'dick',
#  'amending',
#  'incomparable',
#  'startled',
#  'installed',
#  'lawford',
#  "capital's",
#  '5-day',
#  'papers',
#  'forces',
#  "mccloy's",
#  'homeowners',
#  'idols',
#  'ballets',
#  'self',
#  'bryson',
#  'teamsters',
#  'picketed',
#  'dignity',
#  'rickards',
#  'water',
#  'note',
#  'richard',
#  'peoples',
#  'maynor',
#  '1919',
#  'e.',
#  'treadwell',
#  'perturbed',
#  'tripled',
#  'headmaster',
#  'glamor',
#  'mustang',
#  'stalemate',
#  'coal',
#  '175',
#  'strayed',
#  'labor-management',
#  'tenure',
#  'reconvention',
#  'trends',
#  'strenuous',
#  'stupidity',
#  '1899',
#  'every',
#  'competition',
#  'affirmation',
#  'physician',
#  'beaming',
#  'ringside',
#  "warehouseman's",
#  'chiang',
#  '1922',
#  'resort',
#  'stopovers',
#  'nodded',
#  'stimulant',
#  'bertorelli',
#  'frustrated',
#  'shade',
#  'soviet',
#  'squarely',
#  'outdoors',
#  '4-1/2%',
#  'judge',
#  'sharing',
#  'questions',
#  'pickers',
#  'forcing',
#  'revenuers',
#  'moments',
#  'paycheck',
#  'improve',
#  'double',
#  'schley',
#  'stanley',
#  'waggin',
#  'heinkel',
#  'enthralled',
#  'stevedore',
#  'hill',
#  'congressional',
#  'banjo',
#  'jet',
#  'embezzlement',
#  'wash',
#  'january',
#  'probate',
#  'shoes',
#  'brownings',
#  'were',
#  'c',
#  'presidential',
#  '$37',
#  'franchise',
#  'signals',
#  "students'",
#  'dish',
#  'unmeritorious',
#  'darrow',
#  'propelling',
#  'oppose',
#  'forecasts',
#  'profili',
#  'describing',
#  'efficient',
#  'further',
#  'dazzler',
#  '69',
#  'noel',
#  'pleasant',
#  'pertained',
#  'completion',
#  'main',
#  'gradually',
#  'protect',
#  '$18.2',
#  'blumenthal',
#  'dennis',
#  'walnut',
#  'g.',
#  '13-5',
#  'kimmell',
#  'democratic-endorsed',
#  'marine',
#  'france',
#  'packs',
#  'greater',
#  'trimmed',
#  'fierce',
#  'kern',
#  'spraying',
#  'ultimate',
#  '5835',
#  'experiencing',
#  'pictured',
#  'numerous',
#  'administered',
#  '1960s',
#  'distinguished',
#  '1910-14',
#  'loop',
#  'does',
#  'author',
#  'gas',
#  "coach's",
#  'grayson',
#  'stitch',
#  'authorize',
#  '200',
#  'glass',
#  'relatively',
#  'rayburn',
#  '1959',
#  'banned',
#  'lettered',
#  'consultant',
#  'genevieve',
#  'hired',
#  'eustis',
#  'east',
#  'confrontation',
#  'tex.',
#  'missed',
#  '2269',
#  '1940',
#  'opposite',
#  "contractor's",
#  'posed',
#  'adair',
#  'braves',
#  'appliances',
#  'towering',
#  'derived',
#  'here',
#  'nuns',
#  'imagines',
#  'substance',
#  'uniformed',
#  '65%',
#  'stages',
#  'deteriorating',
#  '121',
#  'education',
#  'therefore',
#  'crews',
#  '.',
#  'during',
#  'infant',
#  'appreciation',
#  'developments',
#  'deal',
#  'arm',
#  'brother-in-law',
#  'planners',
#  'smallwood',
#  'workers',
#  'foreign',
#  'ex-mrs.',
#  '798',
#  'worsens',
#  'distinctly',
#  'heralded',
#  'lasted',
#  'publicity',
#  'compassionate',
#  'suggested',
#  'larceny',
#  'bounds',
#  'provides',
#  'scrambled',
#  'd.c.',
#  'dead',
#  'kanin',
#  'fourth-down',
#  '$100,000',
#  'seize',
#  'buchheister',
#  'nick',
#  'ponies',
#  'dec.',
#  'south',
#  "junior's",
#  'dealing',
#  "engineers'",
#  'carson',
#  'sandra',
#  'ratification',
#  'miscount',
#  'island',
#  'staffed',
#  'hearty',
#  'dependence',
#  '1688',
#  'process',
#  'replies',
#  'dominated',
#  'beaten',
#  'greenwood',
#  'upheld',
#  "fardulli's",
#  'flag-stick',
#  'tech.',
#  'threats',
#  '1952',
#  'lumumba',
#  'underdeveloped',
#  'particular',
#  'sculptured',
#  'recommendations',
#  'puddingstone',
#  'low-flying',
#  'erred',
#  'identically',
#  'spending',
#  'stoppages',
#  'pad',
#  'acclimatized',
#  'culpas',
#  'hard',
#  'crypt',
#  'rapped',
#  'statistical',
#  'scherer',
#  'granular-type',
#  'treated',
#  'relations',
#  'orleans',
#  'seconds',
#  'succeeding',
#  'nuttall',
#  'cooke',
#  'bootle',
#  'goods',
#  'bludgeon',
#  'egerton',
#  'downtown',
#  'urban',
#  'aims',
#  'salem',
#  'squabbles',
#  'nations',
#  "manufacturers'",
#  'scene',
#  'fuels',
#  'lyle',
#  'practices',
#  'paid-for',
#  'okla.',
#  'loading',
#  'upi',
#  '$1,600',
#  'landscaped',
#  'ligget',
#  'big-league',
#  'holabird',
#  'adult',
#  'critic',
#  'passed',
#  'closer',
#  'dorsey',
#  'slackening',
#  'vernor',
#  'you',
#  'went',
#  'anderlini',
#  'struggles',
#  'zinman',
#  'competitive',
#  'there',
#  'yardstick',
#  'establishing',
#  'recalls',
#  'opportunity',
#  "chronicle's",
#  'moffett',
#  'canvassed',
#  'surprise',
#  '$457,000',
#  '3-10',
#  'socks',
#  'joints',
#  'inlaid',
#  'stern',
#  'balenciaga',
#  'gave',
#  '1957',
#  'collided',
#  'trigg',
#  'envision',
#  'gesture',
#  "republicans'",
#  'underwriting',
#  'lull',
#  'chance',
#  'swearing',
#  'okinawa',
#  'encouraging',
#  'capabilities',
#  'aquinas',
#  'gaynor',
#  'underwater',
#  'exports',
#  'profit',
#  'safety',
#  'unquestionably',
#  'pointed',
#  'literature',
#  'liberals',
#  'stoll',
#  'ghastly',
#  'undergone',
#  'poured',
#  'staggered',
#  '$1,500,000',
#  'deemed',
#  'vietnamese',
#  'madame',
#  'unlike',
#  'hits',
#  'ninety-nine',
#  'accommodated',
#  'sponsoring',
#  'opening',
#  'extend',
#  'lavishly',
#  'nowhere',
#  'risk',
#  'guatemala',
#  'accurate',
#  'drive-in',
#  'idealist',
#  'u.s.',
#  'power',
#  'switching',
#  'slaughter',
#  'mazeroski',
#  'savannah',
#  'employ',
#  'handicapped',
#  'pastime',
#  'latch',
#  'ideal',
#  'three-day',
#  'within',
#  'impossibly',
#  'wheat',
#  'fastest',
#  'run',
#  '1937',
#  'big',
#  'mcn.',
#  'violating',
#  '237%',
#  'bedrooms',
#  'electricity',
#  'dorenzo',
#  'farrell',
#  'discharge',
#  'appealing',
#  'onetime',
#  'niece',
#  'swearing-in',
#  'crossing',
#  'courbet',
#  'remark',
#  '20,000',
#  "nation's",
#  'music',
#  'grace',
#  '187.5',
#  'parker',
#  'unhappy',
#  'retirements',
#  'knows',
#  '49ers',
#  'grandparents',
#  'recounting',
#  '$253,355,000',
#  'drizzly',
#  "palmer's",
#  'been',
#  'pace',
#  'better',
#  'criminals',
#  'oliver',
#  '$80,738',
#  'collection',
#  'smashed',
#  'arnold',
#  'hardy',
#  'wear',
#  'expensive',
#  'religious',
#  'requirement',
#  'voted',
#  'preview',
#  'instrument',
#  'underprivileged',
#  'violent',
#  'heroin',
#  'underlying',
#  'ham',
#  'disable',
#  'candor',
#  'dist.',
#  'esprit',
#  'visits',
#  'r.l.',
#  'sledding',
#  'sugar',
#  'side',
#  'kroger',
#  'philosopher',
#  'three-hour',
#  'typewriters',
#  'advances',
#  'brigantine',
#  'forms',
#  'researchers',
#  'well-armed',
#  'representations',
#  'fatal',
#  'faculty',
#  '$8.50',
#  'divided',
#  'flowed',
#  'pile',
#  'washed-out',
#  'moves',
#  'parks',
#  'tractor',
#  'toughness',
#  'forthcoming',
#  'almost',
#  'repertory',
#  'planner',
#  'send',
#  'motto',
#  'erection',
#  'crime',
#  'crackpots',
#  '3-inch',
#  'p.m.',
#  'vitally',
#  'craig',
#  'penalized',
#  'spokesman',
#  'forty-year',
#  'sixth-sense',
#  'cincinnati',
#  'givers',
#  'couve',
#  'plan',
#  'staffs',
#  'flower',
#  'laotian',
#  'dewey',
#  'real',
#  'bester',
#  'bean',
#  'nearby',
#  'over-night',
#  'acid',
#  'sparkle',
#  'master',
#  'southwest',
#  'three-building',
#  'adcock',
#  "league's",
#  '4:18',
#  'georgia-pacific',
#  'bring',
#  'a.a.u.',
#  'disposal',
#  'saute',
#  'mink',
#  'book-selection',
#  'possessive',
#  '2.5%',
#  'reiterate',
#  'lived',
#  'release',
#  'high-density',
#  'shaw',
#  'one-week-old',
#  'talents',
#  'rackmil',
#  'complaining',
#  'surgery',
#  'hostages',
#  'switch',
#  'go',
#  'unchecked',
#  'allison',
#  'thoroughfare',
#  'ten-hour',
#  '361',
#  'thru',
#  'us',
#  'capitalist',
#  'oxford',
#  'modernized',
#  'traveler',
#  'truman',
#  'overpowered',
#  'smythe',
#  'commerce',
#  'edwards',
#  'indictment',
#  'orchids',
#  'uncas',
#  'firing',
#  'clifford',
#  "a's",
#  'severly',
#  'stark',
#  'votes',
#  'willingness',
#  'trouble',
#  'eddie',
#  'walkout',
#  'raymondville',
#  'scarcely',
#  'working',
#  'factor',
#  'warned',
#  'negotiations',
#  'bernie',
#  'exhibited',
#  'walter',
#  'lace',
#  'dignitaries',
#  'president-elect',
#  'tolls',
#  'hollander',
#  'crucified',
#  'affect',
#  'chico',
#  'elements',
#  'majorities',
#  'pressed-paper',
#  'politely',
#  'detonation',
#  'fergeson',
#  "mills's",
#  'fouled',
#  'bernardine',
#  '100%',
#  'geography',
#  'loaded',
#  'buck',
#  'embedded',
#  'raising',
#  'crashed',
#  'climbed',
#  'contracts',
#  'suit',
#  'arkansas',
#  'wissahickon',
#  '1865',
#  'me',
#  'wholesale',
#  'fabrics',
#  '55',
#  'studying',
#  'vieth',
#  '5847',
#  'tense',
#  'alba',
#  'leary',
#  'undoubtedly',
#  'high-school',
#  'socialized',
#  'join',
#  'industrial',
#  'undertakes',
#  'deposit',
#  'southwestern',
#  'pro-western',
#  'andrew',
#  'communications',
#  'whee',
#  'relationships',
#  'very',
#  'bachelor',
#  'globe-democrat',
#  'crucial',
#  'conversation',
#  'consulate',
#  'only',
#  'we',
#  'carruthers',
#  'bed-time',
#  'technicians',
#  'vehicle',
#  'due',
#  'prominently',
#  'unique',
#  'initiating',
#  'object',
#  '33-man',
#  'skid',
#  'sybert',
#  'tareytown',
#  'priced',
#  'champion',
#  'waters',
#  'gain',
#  'wise',
#  'mayor-nominate',
#  'comprise',
#  'hubert',
#  'jolly',
#  '300,000',
#  'robertsons',
#  'angeles',
#  'companionship',
#  'contact',
#  'sylvania',
#  'hills',
#  'electrical',
#  'plenty',
#  'southerners',
#  'cd',
#  'cyclical',
#  'instrumentals',
#  'notably',
#  'dental',
#  'referendum',
#  'recipients',
#  'superior',
#  "chicago's",
#  'fireside',
#  'churchmen',
#  'princess',
#  'marked',
#  'gals',
#  'joey',
#  'abuse',
#  'gotham',
#  'purchase',
#  'border',
#  'pitcher',
#  'idol',
#  'danger',
#  'woodcarver',
#  'destroyer',
#  'hudson',
#  'governs',
#  'solicitor',
#  'skiddy',
#  'groove',
#  'conversion',
#  'percentage',
#  'slower',
#  'sees',
#  'friends',
#  'jerry',
#  '380-foot',
#  'awareness',
#  'slow',
#  'revealed',
#  'respond',
#  'airport',
#  '87th',
#  'prix',
#  'inferior',
#  'sportswriter',
#  '50,000,000',
#  "monday's",
#  '1213',
#  'tractors',
#  '3-month',
#  'attempt',
#  'congolese',
#  'bum',
#  'bexar',
#  'ineffectual',
#  'equipment',
#  'computers',
#  'convicted',
#  'butlers',
#  'frankie',
#  'fulton',
#  'foreman',
#  'fourteen-nation',
#  'scholar',
#  'hong',
#  'tosses',
#  'bit',
#  'harry',
#  'verify',
#  'characteristic',
#  'led',
#  'transit',
#  'simultaneous',
#  'eve',
#  'rates',
#  'micro-microcurie',
#  'miniver',
#  'fairy',
#  'pastors',
#  'resident',
#  'realistic',
#  '3300',
#  'compacts',
#  'chardon',
#  'jean',
#  'regents',
#  'playable',
#  "women's",
#  '$37,500',
#  'peaks',
#  "rickey's",
#  'positive',
#  'yuri',
#  '$28,700,000',
#  'judges',
#  'retrenching',
#  'adventures',
#  'plague',
#  'costumes',
#  '(',
#  'wegener',
#  'insects',
#  'hyde',
#  'abel',
#  'knight',
#  'unemployment',
#  'vroman',
#  'neveh',
#  'oceania',
#  'effectively',
#  "speaker's",
#  'begins',
#  '20%',
#  'ladies',
#  'agents',
#  '65',
#  'honorary',
#  'absorb',
#  'starter',
#  'cal.',
#  'swipe',
#  'engage',
#  'publicly',
#  'communism',
#  'budgets',
#  'scoring',
#  'neighbor',
#  'sokol',
#  'enforcement',
#  'warden',
#  'newport',
#  'vicinity',
#  'constitution',
#  'veteran',
#  'something',
#  'pun',
#  'lisle',
#  "mechanic's",
#  'tuesday',
#  "nato's",
#  'enabled',
#  'mentioned',
#  'houghton',
#  'blanche',
#  'privilege',
#  'path',
#  'stockholders',
#  'eventual',
#  'virtues',
#  'interference',
#  'courageous',
#  'parents',
#  'bloodstream',
#  'sleeps',
#  'licensing',
#  'imbroglio',
#  'emerges',
#  'idealism',
#  'pursued',
#  "glimco's",
#  'german',
#  '7',
#  'reputedly',
#  '59',
#  "mayor's",
#  'suffered',
#  'chapelles',
#  'church-state',
#  'amicable',
#  'holiday',
#  'ex-singer',
#  'executive',
#  'so-far',
#  'dimaggio',
#  'hayward',
#  'coordination',
#  ...]

# %% [markdown]
# $$P(w)=U(w)^{3/4}/Z$$

# %%
unigram_table = []

for v in vocabs:
    uw = word_count[v] / num_total_words
    uw_alpha = int((uw ** 0.75) / z)
    unigram_table.extend([v] * uw_alpha)
    
Counter(unigram_table)
# Out:
# Counter({'the': 126,
#          ',': 108,
#          '.': 89,
#          'of': 69,
#          'and': 56,
#          'a': 55,
#          'to': 55,
#          'in': 53,
#          'for': 30,
#          'that': 27,
#          'was': 24,
#          '``': 24,
#          'is': 24,
#          "''": 24,
#          'on': 23,
#          'he': 22,
#          'at': 22,
#          'with': 20,
#          'as': 19,
#          'be': 19,
#          'by': 18,
#          'it': 18,
#          'said': 16,
#          'his': 16,
#          'will': 15,
#          'from': 14,
#          'are': 13,
#          'an': 13,
#          'this': 13,
#          ';': 13,
#          'had': 12,
#          '--': 12,
#          'but': 12,
#          'has': 12,
#          'were': 11,
#          'not': 11,
#          'mrs.': 11,
#          'they': 11,
#          'would': 11,
#          'who': 11,
#          'have': 11,
#          'their': 10,
#          'which': 10,
#          'new': 10,
#          'there': 9,
#          'been': 9,
#          'one': 9,
#          '(': 8,
#          'more': 8,
#          'all': 8,
#          'two': 8,
#          'up': 8,
#          'its': 8,
#          'when': 8,
#          'or': 8,
#          ')': 8,
#          'mr.': 8,
#          'last': 8,
#          'out': 8,
#          'i': 8,
#          'other': 8,
#          'after': 7,
#          'state': 7,
#          'than': 7,
#          'first': 7,
#          ':': 7,
#          'president': 7,
#          'about': 7,
#          'year': 7,
#          'only': 6,
#          'over': 6,
#          'also': 6,
#          'some': 6,
#          'no': 6,
#          'her': 6,
#          'into': 6,
#          'home': 6,
#          'we': 5,
#          'him': 5,
#          'three': 5,
#          '?': 5,
#          'under': 5,
#          'made': 5,
#          'may': 5,
#          'any': 5,
#          'them': 5,
#          'before': 5,
#          'could': 5,
#          'if': 5,
#          'time': 5,
#          'city': 5,
#          'now': 5,
#          'years': 5,
#          'week': 5,
#          'school': 5,
#          'what': 5,
#          'house': 5,
#          'can': 5,
#          'here': 4,
#          'you': 4,
#          'john': 4,
#          'since': 4,
#          'kennedy': 4,
#          'high': 4,
#          'day': 4,
#          'committee': 4,
#          'against': 4,
#          'do': 4,
#          'government': 4,
#          'university': 4,
#          'four': 4,
#          'off': 4,
#          'each': 4,
#          'back': 4,
#          'she': 4,
#          'american': 4,
#          'these': 4,
#          'those': 4,
#          'both': 4,
#          'national': 4,
#          'get': 4,
#          'night': 4,
#          'board': 4,
#          'such': 4,
#          'most': 4,
#          'so': 4,
#          'did': 4,
#          'members': 4,
#          'bill': 4,
#          'man': 4,
#          'program': 4,
#          'then': 4,
#          'many': 4,
#          'work': 4,
#          'while': 3,
#          'education': 3,
#          'during': 3,
#          'u.s.': 3,
#          'plan': 3,
#          'five': 3,
#          'world': 3,
#          'club': 3,
#          'tax': 3,
#          'public': 3,
#          'children': 3,
#          'just': 3,
#          'make': 3,
#          'texas': 3,
#          'car': 3,
#          'monday': 3,
#          'meeting': 3,
#          'where': 3,
#          'like': 3,
#          'told': 3,
#          'much': 3,
#          "'": 3,
#          'got': 3,
#          'washington': 3,
#          'even': 3,
#          'yesterday': 3,
#          'long': 3,
#          'men': 3,
#          'today': 3,
#          'local': 3,
#          'miss': 3,
#          'million': 3,
#          'through': 3,
#          'without': 3,
#          'down': 3,
#          'another': 3,
#          'cent': 3,
#          'game': 3,
#          'our': 3,
#          'took': 3,
#          'mantle': 3,
#          'service': 3,
#          'jury': 3,
#          'business': 3,
#          'court': 3,
#          'system': 3,
#          'jr.': 3,
#          'sales': 3,
#          'administration': 3,
#          'however': 3,
#          'family': 3,
#          'united': 3,
#          'per': 3,
#          '1': 3,
#          'set': 3,
#          'being': 3,
#          'county': 3,
#          'between': 3,
#          'take': 3,
#          'good': 3,
#          'sunday': 3,
#          'york': 3,
#          'federal': 3,
#          'white': 3,
#          'must': 3,
#          'states': 3,
#          'dallas': 3,
#          'people': 3,
#          'way': 3,
#          'should': 3,
#          'because': 3,
#          'company': 3,
#          'north': 2,
#          'future': 2,
#          'result': 2,
#          'use': 2,
#          'richard': 2,
#          'e.': 2,
#          'every': 2,
#          'soviet': 2,
#          'judge': 2,
#          'does': 2,
#          'foreign': 2,
#          'went': 2,
#          'run': 2,
#          'big': 2,
#          'better': 2,
#          'p.m.': 2,
#          'go': 2,
#          'me': 2,
#          'very': 2,
#          'equipment': 2,
#          'tuesday': 2,
#          'a.': 2,
#          'meet': 2,
#          'library': 2,
#          'says': 2,
#          'little': 2,
#          'political': 2,
#          'chairman': 2,
#          'taken': 2,
#          'group': 2,
#          'show': 2,
#          'problem': 2,
#          'countries': 2,
#          'early': 2,
#          'found': 2,
#          'conference': 2,
#          'james': 2,
#          'st.': 2,
#          'saturday': 2,
#          'series': 2,
#          'same': 2,
#          'announced': 2,
#          'union': 2,
#          'church': 2,
#          'bonds': 2,
#          'center': 2,
#          'second': 2,
#          'aid': 2,
#          'part': 2,
#          'director': 2,
#          'ever': 2,
#          'runs': 2,
#          'few': 2,
#          '!': 2,
#          'interest': 2,
#          'j.': 2,
#          'central': 2,
#          '1960': 2,
#          'council': 2,
#          'best': 2,
#          'right': 2,
#          '10': 2,
#          'present': 2,
#          'stock': 2,
#          'party': 2,
#          'know': 2,
#          'think': 2,
#          'months': 2,
#          'team': 2,
#          'came': 2,
#          'congo': 2,
#          'top': 2,
#          'small': 2,
#          'district': 2,
#          'money': 2,
#          'end': 2,
#          'weeks': 2,
#          'began': 2,
#          'staff': 2,
#          'still': 2,
#          'office': 2,
#          'enough': 2,
#          'six': 2,
#          'until': 2,
#          'case': 2,
#          'act': 2,
#          'vote': 2,
#          'open': 2,
#          'hospital': 2,
#          'record': 2,
#          'c.': 2,
#          'palmer': 2,
#          'season': 2,
#          'higher': 2,
#          'baseball': 2,
#          'laws': 2,
#          'held': 2,
#          'area': 2,
#          'republican': 2,
#          'secretary': 2,
#          'asked': 2,
#          'communist': 2,
#          'needed': 2,
#          'past': 2,
#          'election': 2,
#          'possible': 2,
#          'give': 2,
#          'military': 2,
#          'days': 2,
#          'session': 2,
#          'together': 2,
#          'william': 2,
#          'friday': 2,
#          'march': 2,
#          'association': 2,
#          'league': 2,
#          'police': 2,
#          'how': 2,
#          'special': 2,
#          'field': 2,
#          'h.': 2,
#          'left': 2,
#          'report': 2,
#          'hit': 2,
#          'daughter': 2,
#          'co.': 2,
#          'again': 2,
#          'general': 2,
#          'own': 2,
#          'player': 2,
#          'college': 2,
#          'department': 2,
#          'wife': 2,
#          'fire': 2,
#          'added': 2,
#          'among': 2,
#          'might': 2,
#          'several': 2,
#          'called': 2,
#          'place': 2,
#          'street': 2,
#          'see': 2,
#          'labor': 2,
#          'firm': 2,
#          'reported': 2,
#          'funds': 2,
#          'country': 2,
#          'help': 2,
#          'young': 2,
#          'next': 2,
#          'given': 2,
#          'senate': 2,
#          'play': 2,
#          'late': 2,
#          'received': 2,
#          'laos': 2,
#          'total': 2,
#          'ball': 2,
#          '4': 2,
#          '&': 2,
#          'eight': 2,
#          'month': 2,
#          'former': 2,
#          'dr.': 2,
#          'ago': 2,
#          'annual': 2,
#          'later': 2,
#          '1961': 2,
#          'war': 2,
#          's.': 2,
#          'around': 2,
#          '2': 2,
#          'w.': 2,
#          'number': 2,
#          'project': 2,
#          'major': 2,
#          'maris': 2,
#          'well': 2,
#          'expected': 2,
#          'schools': 2,
#          'along': 2,
#          'law': 2,
#          'hotel': 2,
#          'old': 2,
#          'never': 2,
#          'start': 2,
#          'member': 2,
#          'put': 2,
#          'too': 2,
#          'international': 2,
#          'democratic': 2,
#          'robert': 2,
#          'pay': 2,
#          'need': 2,
#          'far': 2,
#          'issue': 2,
#          'come': 2,
#          'market': 2,
#          'third': 2,
#          'industry': 2,
#          'my': 2,
#          'b.': 2,
#          'great': 2,
#          'movement': 1,
#          'boston': 1,
#          'themselves': 1,
#          'shown': 1,
#          'spirit': 1,
#          "i'm": 1,
#          '6': 1,
#          'growth': 1,
#          'primary': 1,
#          'forces': 1,
#          'water': 1,
#          'coal': 1,
#          'double': 1,
#          'hill': 1,
#          'further': 1,
#          'g.': 1,
#          'greater': 1,
#          'gas': 1,
#          '200': 1,
#          '1959': 1,
#          'east': 1,
#          'workers': 1,
#          'south': 1,
#          'island': 1,
#          'hard': 1,
#          'relations': 1,
#          'orleans': 1,
#          'nations': 1,
#          'passed': 1,
#          'opportunity': 1,
#          'gave': 1,
#          'hits': 1,
#          'opening': 1,
#          'power': 1,
#          'within': 1,
#          'music': 1,
#          'collection': 1,
#          'arnold': 1,
#          'religious': 1,
#          'side': 1,
#          'faculty': 1,
#          'almost': 1,
#          'real': 1,
#          'bring': 1,
#          'us': 1,
#          'working': 1,
#          'negotiations': 1,
#          'champion': 1,
#          'angeles': 1,
#          'friends': 1,
#          'congolese': 1,
#          'fulton': 1,
#          'led': 1,
#          'veteran': 1,
#          'something': 1,
#          '7': 1,
#          'executive': 1,
#          'statement': 1,
#          'm.': 1,
#          'bond': 1,
#          'pittsburgh': 1,
#          'matter': 1,
#          'premier': 1,
#          'british': 1,
#          'town': 1,
#          'kind': 1,
#          'smith': 1,
#          'san': 1,
#          'trade': 1,
#          'houston': 1,
#          'already': 1,
#          'wagner': 1,
#          'verdict': 1,
#          '15': 1,
#          'used': 1,
#          'shares': 1,
#          'anti-trust': 1,
#          'room': 1,
#          'oct.': 1,
#          'employees': 1,
#          'hughes': 1,
#          'appeared': 1,
#          'mickey': 1,
#          'want': 1,
#          'democrats': 1,
#          'bank': 1,
#          'study': 1,
#          'complete': 1,
#          'base': 1,
#          'welfare': 1,
#          'person': 1,
#          'rather': 1,
#          'become': 1,
#          'live': 1,
#          'strike': 1,
#          'spring': 1,
#          'ohio': 1,
#          "doesn't": 1,
#          "year's": 1,
#          'moritz': 1,
#          'addition': 1,
#          'youth': 1,
#          'clearly': 1,
#          'term': 1,
#          'leading': 1,
#          'certain': 1,
#          'jack': 1,
#          'became': 1,
#          'able': 1,
#          'offered': 1,
#          'immediately': 1,
#          'considered': 1,
#          'housing': 1,
#          'graduate': 1,
#          'authority': 1,
#          'coast': 1,
#          'mayor': 1,
#          'find': 1,
#          'services': 1,
#          'actually': 1,
#          'havana': 1,
#          'mark': 1,
#          'needs': 1,
#          'done': 1,
#          'headquarters': 1,
#          'knew': 1,
#          'social': 1,
#          'francisco': 1,
#          'el': 1,
#          'miles': 1,
#          'though': 1,
#          'throughout': 1,
#          'howard': 1,
#          'afternoon': 1,
#          'drive': 1,
#          'once': 1,
#          'carry': 1,
#          'presented': 1,
#          'means': 1,
#          'west': 1,
#          'floor': 1,
#          'luncheon': 1,
#          'single': 1,
#          'entire': 1,
#          'agreement': 1,
#          'investigation': 1,
#          'moved': 1,
#          'nuclear': 1,
#          'especially': 1,
#          'traffic': 1,
#          'armed': 1,
#          'despite': 1,
#          "didn't": 1,
#          'continue': 1,
#          'leaders': 1,
#          'making': 1,
#          'boy': 1,
#          'salary': 1,
#          'unit': 1,
#          'henry': 1,
#          'earlier': 1,
#          'l.': 1,
#          'additional': 1,
#          'july': 1,
#          'turnpike': 1,
#          'investment': 1,
#          'manager': 1,
#          'running': 1,
#          'read': 1,
#          'price': 1,
#          'felt': 1,
#          'failed': 1,
#          'medical': 1,
#          'america': 1,
#          'citizens': 1,
#          'sen.': 1,
#          'population': 1,
#          'bills': 1,
#          'race': 1,
#          'condition': 1,
#          'neither': 1,
#          'operation': 1,
#          'billion': 1,
#          'beat': 1,
#          'happy': 1,
#          'known': 1,
#          'community': 1,
#          'coming': 1,
#          'question': 1,
#          'fourth': 1,
#          'returned': 1,
#          'georgia': 1,
#          'address': 1,
#          'urged': 1,
#          'products': 1,
#          'charter': 1,
#          'necessary': 1,
#          'arms': 1,
#          'corps': 1,
#          'r.': 1,
#          'evening': 1,
#          'serious': 1,
#          'plans': 1,
#          'research': 1,
#          'post': 1,
#          'fund': 1,
#          'seven': 1,
#          '13': 1,
#          'name': 1,
#          'assistant': 1,
#          'key': 1,
#          'explained': 1,
#          'let': 1,
#          'hands': 1,
#          'wide': 1,
#          'least': 1,
#          'close': 1,
#          'reasons': 1,
#          'candidate': 1,
#          '25': 1,
#          'air': 1,
#          'book': 1,
#          'turn': 1,
#          '19': 1,
#          'reports': 1,
#          'word': 1,
#          'thing': 1,
#          'fight': 1,
#          'evidence': 1,
#          'emory': 1,
#          '11': 1,
#          'event': 1,
#          'black': 1,
#          'student': 1,
#          'expansion': 1,
#          'russia': 1,
#          'bob': 1,
#          'thompson': 1,
#          'morton': 1,
#          'care': 1,
#          'really': 1,
#          'across': 1,
#          'others': 1,
#          'strong': 1,
#          'lawrence': 1,
#          'fashion': 1,
#          'los': 1,
#          'division': 1,
#          'view': 1,
#          'joseph': 1,
#          'attorney': 1,
#          'contract': 1,
#          '12': 1,
#          'christian': 1,
#          'professional': 1,
#          'f.': 1,
#          'leadership': 1,
#          'job': 1,
#          'fair': 1,
#          'continued': 1,
#          'why': 1,
#          'art': 1,
#          'possibility': 1,
#          'americans': 1,
#          'barnett': 1,
#          '3': 1,
#          'hillsboro': 1,
#          'couple': 1,
#          'force': 1,
#          'rev.': 1,
#          'mitchell': 1,
#          'green': 1,
#          'station': 1,
#          'concerned': 1,
#          'prevent': 1,
#          'perhaps': 1,
#          'action': 1,
#          'using': 1,
#          'development': 1,
#          'investors': 1,
#          'spent': 1,
#          'move': 1,
#          'say': 1,
#          'reason': 1,
#          'catholic': 1,
#          'color': 1,
#          'chicago': 1,
#          'plane': 1,
#          'example': 1,
#          'governor': 1,
#          'clear': 1,
#          'current': 1,
#          'prices': 1,
#          'toward': 1,
#          'property': 1,
#          'share': 1,
#          'level': 1,
#          'makes': 1,
#          'designed': 1,
#          'churches': 1,
#          'hear': 1,
#          'listed': 1,
#          'farm': 1,
#          'owners': 1,
#          'students': 1,
#          'whose': 1,
#          'campaign': 1,
#          'required': 1,
#          'southeast': 1,
#          'defense': 1,
#          'robinson': 1,
#          'wall': 1,
#          'atlanta': 1,
#          'winning': 1,
#          'lead': 1,
#          'test': 1,
#          'honor': 1,
#          'short': 1,
#          'hope': 1,
#          'vice': 1,
#          'times': 1,
#          'income': 1,
#          'parties': 1,
#          'stand': 1,
#          'charged': 1,
#          'section': 1,
#          '22': 1,
#          'shop': 1,
#          'limited': 1,
#          'employes': 1,
#          'grand': 1,
#          'chief': 1,
#          'performance': 1,
#          'free': 1,
#          'feel': 1,
#          'thomas': 1,
#          'talk': 1,
#          '20': 1,
#          'private': 1,
#          'heard': 1,
#          'dropped': 1,
#          'voters': 1,
#          'books': 1,
#          '14': 1,
#          'fees': 1,
#          'look': 1,
#          'front': 1,
#          'cars': 1,
#          'commission': 1,
#          'khrushchev': 1,
#          'secrets': 1,
#          'sixth': 1,
#          'wages': 1,
#          'theater': 1,
#          'served': 1,
#          'husband': 1,
#          'daily': 1,
#          'sense': 1,
#          'trial': 1,
#          'summer': 1,
#          'include': 1,
#          'portland': 1,
#          'jones': 1,
#          'having': 1,
#          'build': 1,
#          'nor': 1,
#          'father': 1,
#          'headed': 1,
#          'ap': 1,
#          'belgians': 1,
#          'june': 1,
#          'either': 1,
#          'cost': 1,
#          'legislators': 1,
#          'period': 1,
#          'included': 1,
#          'coach': 1,
#          'conspiracy': 1,
#          'order': 1,
#          '18': 1,
#          'cut': 1,
#          'particularly': 1,
#          'nation': 1,
#          'admitted': 1,
#          'worth': 1,
#          'head': 1,
#          'programs': 1,
#          'unions': 1,
#          'persons': 1,
#          'stein': 1,
#          'golf': 1,
#          'except': 1,
#          'important': 1,
#          'cuba': 1,
#          'lee': 1,
#          'getting': 1,
#          'tried': 1,
#          'joined': 1,
#          'organization': 1,
#          'denver': 1,
#          'your': 1,
#          'providence': 1,
#          'lines': 1,
#          'games': 1,
#          'charles': 1,
#          'players': 1,
#          'attack': 1,
#          'elected': 1,
#          'blue': 1,
#          '9': 1,
#          'rules': 1,
#          'change': 1,
#          'reached': 1,
#          'revenues': 1,
#          'followed': 1,
#          'letters': 1,
#          'weekend': 1,
#          'machinery': 1,
#          'davis': 1,
#          'thought': 1,
#          'thursday': 1,
#          'changes': 1,
#          'frank': 1,
#          'taking': 1,
#          'minutes': 1,
#          'construction': 1,
#          'dinner': 1,
#          'officers': 1,
#          'playing': 1,
#          'hole': 1,
#          'wednesday': 1,
#          'lost': 1,
#          'affairs': 1,
#          "don't": 1,
#          '60': 1,
#          'd.': 1,
#          'wanted': 1,
#          'u.': 1,
#          'groups': 1,
#          'merely': 1,
#          'age': 1,
#          'gin': 1,
#          'geneva': 1,
#          'tell': 1,
#          'receive': 1,
#          'victory': 1,
#          'building': 1,
#          'knee': 1,
#          'bankers': 1,
#          'driving': 1,
#          'nearly': 1,
#          'round': 1,
#          'immediate': 1,
#          'audience': 1,
#          'philadelphia': 1,
#          'paid': 1,
#          'security': 1,
#          'indicated': 1,
#          'cases': 1,
#          'half': 1,
#          'counties': 1,
#          'scheduled': 1,
#          'grants': 1,
#          'tournament': 1,
#          'feet': 1,
#          'control': 1,
#          'p.': 1,
#          'charges': 1,
#          'pass': 1,
#          'cannot': 1,
#          'yards': 1,
#          'outside': 1,
#          'score': 1,
#          'situation': 1,
#          'developed': 1,
#          'away': 1,
#          'recent': 1,
#          'struck': 1,
#          'sent': 1,
#          'attend': 1,
#          '17': 1,
#          "kennedy's": 1,
#          'caused': 1,
#          'grant': 1,
#          'according': 1,
#          'agency': 1,
#          'whole': 1,
#          'recently': 1,
#          'successful': 1,
#          'including': 1,
#          '30': 1,
#          'final': 1,
#          'feb.': 1,
#          'tomorrow': 1,
#          'am': 1,
#          'financial': 1,
#          'planning': 1,
#          'u.n.': 1,
#          'george': 1,
#          'apartment': 1,
#          'beach': 1,
#          'previous': 1,
#          'son': 1,
#          'giants': 1,
#          'cotton': 1,
#          'turned': 1,
#          'point': 1,
#          'jim': 1,
#          'started': 1,
#          'avenue': 1,
#          'anyone': 1,
#          'passing': 1,
#          'full': 1,
#          'army': 1,
#          'saw': 1,
#          'stage': 1,
#          'guests': 1,
#          'rural': 1,
#          'jan.': 1,
#          'seemed': 1,
#          'park': 1,
#          'value': 1,
#          'straight': 1,
#          'williams': 1,
#          'payroll': 1,
#          'whether': 1,
#          'although': 1,
#          'upon': 1,
#          'effective': 1,
#          'walk': 1,
#          'economic': 1,
#          'following': 1,
#          'leader': 1,
#          'battle': 1,
#          'arrested': 1,
#          'road': 1,
#          'himself': 1,
#          'estimated': 1,
#          'ballet': 1,
#          'railroad': 1,
#          'effect': 1,
#          'sold': 1,
#          'track': 1,
#          'david': 1,
#          'costs': 1,
#          'kansas': 1,
#          'official': 1,
#          'mother': 1,
#          '1958': 1,
#          'highway': 1,
#          'press': 1,
#          'legislature': 1,
#          'congress': 1,
#          'rule': 1,
#          'teaching': 1,
#          'believe': 1,
#          'proposed': 1,
#          "president's": 1,
#          'speed': 1,
#          'marriage': 1,
#          'stadium': 1,
#          'support': 1,
#          'involved': 1,
#          'sam': 1,
#          'interested': 1,
#          'lives': 1,
#          'april': 1,
#          'nine': 1,
#          'won': 1,
#          '8': 1,
#          'aj': 1,
#          'increase': 1,
#          "that's": 1,
#          'miami': 1,
#          'hour': 1,
#          'decided': 1,
#          'louis': 1,
#          'calls': 1,
#          'follow': 1,
#          'proposal': 1,
#          'resolution': 1,
#          'mary': 1,
#          'hours': 1,
#          'achievement': 1,
#          'favor': 1,
#          'women': 1,
#          'brought': 1,
#          '100': 1,
#          'independence': 1,
#          'keep': 1,
#          'pitching': 1,
#          ...})

# %% [markdown]
# ## 4. Model
#
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
def prepare_sequence(seq, word2index):
    idxs = list(map(lambda w: word2index[w] if word2index.get(w) is not None else word2index['<UNK>'], seq))
    return torch.LongTensor(idxs)

# %%
import random

def negative_sampling(targets, unigram_table, k):
    batch_size = targets.shape[0]
    neg_samples = []
    for i in range(batch_size):  #(1, k)
        target_index = targets[i].item()
        nsample      = []
        while (len(nsample) < k):
            neg = random.choice(unigram_table)
            if word2index[neg] == target_index:
                continue
            nsample.append(neg)
        neg_samples.append(prepare_sequence(nsample, word2index).reshape(1, -1))
        
    return torch.cat(neg_samples) #batch_size, k

# %%
batch_size = 8
x, y = random_batch(batch_size, corpus)
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)

# %%
k = 5
neg_samples = negative_sampling(y_tensor, unigram_table, k)

# %%
y_tensor[1]
# Out:
# tensor([12411])

# %%
neg_samples[1]
# Out:
# tensor([ 4822,  7439,  4822, 11578,  2869])

# %% [markdown]
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
class SkipgramNeg(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(SkipgramNeg, self).__init__()
        self.embedding_center  = nn.Embedding(voc_size, emb_size)
        self.embedding_outside = nn.Embedding(voc_size, emb_size)
        self.logsigmoid        = nn.LogSigmoid()
    
    def forward(self, center, outside, negative):
        #center, outside:  (bs, 1)
        #negative       :  (bs, k)
        
        center_embed   = self.embedding_center(center) #(bs, 1, emb_size)
        outside_embed  = self.embedding_outside(outside) #(bs, 1, emb_size)
        negative_embed = self.embedding_outside(negative) #(bs, k, emb_size)
        
        uovc           = outside_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, 1)
        ukvc           = -negative_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, k)
        ukvc_sum       = torch.sum(ukvc, 1).reshape(-1, 1) #(bs, 1)
        
        loss           = self.logsigmoid(uovc) + self.logsigmoid(ukvc_sum)
        
        return -torch.mean(loss)

# %%
#test your model
emb_size = 10
voc_size = len(vocabs)
model = SkipgramNeg(voc_size, emb_size)

# %%
loss = model(x_tensor, y_tensor, neg_samples)

# %%
loss
# Out:
# tensor(3.3728, grad_fn=<NegBackward0>)

# %% [markdown]
# ## 5. Training

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import time

losses = []
start_time = time.time()

num_epochs = 1000

for epoch in range(num_epochs):
    
    #get batch
    input_batch, label_batch = random_batch(batch_size, corpus)
    input_tensor = torch.LongTensor(input_batch)
    label_tensor = torch.LongTensor(label_batch)
    
    #predict
    neg_samples = negative_sampling(label_tensor, unigram_table, k)
    loss = model(input_tensor, label_tensor, neg_samples)
    
    #backprogate
    optimizer.zero_grad()
    loss.backward()
    losses.append(loss.item())
    #update alpha
    optimizer.step()
    
    #print the loss
    if (epoch + 1) % 1000 == 0:
        print(f"Epoch {epoch+1:6.0f} | Loss: {loss:2.6f}")

end_time = time.time()
training_time = end_time - start_time
# Out:
# Epoch   1000 | Loss: 3.654001

# %%
print("Final loss:", losses[-1])
print("Training time (s):", training_time)
# Out:
# Final loss: 3.654000759124756
# Training time (s): 2.1021718978881836

# %% [markdown]
# ## 6. Plot the embeddings

# %%
vocabs
# Out:
# ['pennsylvania',
#  'frustrations',
#  "flock's",
#  'chandler',
#  'precipitated',
#  'eliminates',
#  'ocean',
#  'convenient',
#  'zeising',
#  'dapper',
#  'sofas',
#  'movement',
#  'booklists',
#  'constitutional',
#  'educators',
#  'destroy',
#  'summerdale',
#  'long-time',
#  'transportation',
#  'informal',
#  'purpose',
#  'correspondents',
#  'malmud',
#  'particulars',
#  'roller',
#  'surveys',
#  '80',
#  'thereby',
#  'knoll',
#  'collonaded',
#  'while',
#  'federation',
#  'implementation',
#  'missiles',
#  'beautifully',
#  'squared',
#  '1,512',
#  'coasted',
#  'reporters',
#  'treaty',
#  'details',
#  'moore',
#  'brocade',
#  'north',
#  'balance',
#  'barber',
#  'second-place',
#  'forming',
#  'compiled',
#  'strengthened',
#  'leonard',
#  '2-baser',
#  'spahnie',
#  "taxpayer's",
#  'hoover',
#  'reformatory',
#  'sterling',
#  'captured',
#  '70',
#  'youths',
#  'submarine-ball',
#  'gen.',
#  'karns',
#  '17-1/2-inch',
#  'weigh',
#  'tulsa',
#  'future',
#  'wholly-owned',
#  'historian',
#  'prosecutor',
#  'genuine',
#  'bass',
#  'boston',
#  'mont.',
#  'peculiar',
#  'salesman',
#  'result',
#  'fiercest',
#  'hundred',
#  'warnings',
#  'plains',
#  'hold-back',
#  'latter',
#  'fruitful',
#  'scholastics',
#  'themselves',
#  'occupying',
#  'shown',
#  'tired',
#  'seattle',
#  'huntington',
#  'notion',
#  'commitment',
#  'substantially',
#  'temperament',
#  'learned',
#  'plate',
#  'southerner',
#  'exchange',
#  'nickels',
#  'proper',
#  'evelyn',
#  'claus',
#  'robbins',
#  'echoes',
#  'watched',
#  '1933',
#  'peace-loving',
#  'fitted',
#  'fallacious',
#  'roberts',
#  '4:30',
#  'puppet',
#  'chaplin',
#  'breed',
#  'gather',
#  'ablaze',
#  'autumn',
#  "night's",
#  '2-1/2',
#  'processing',
#  'undergoing',
#  'seven-iron',
#  'feeling',
#  '2-3/4',
#  'casualty',
#  'congregation',
#  'denied',
#  'use',
#  'spirit',
#  'pennant',
#  'bids',
#  'hawing',
#  'loewe',
#  "d'etat",
#  'fairly',
#  "i'm",
#  'design-conscious',
#  'incidents',
#  'fellows',
#  'sitting',
#  '44-year-old',
#  'red',
#  '6-foot',
#  'authorities',
#  'airplane',
#  'quarterbacks',
#  'alusik',
#  'fresh',
#  '6',
#  'growth',
#  'purchased',
#  'bookseller',
#  'degree',
#  'alterations',
#  'microfilm',
#  'stockholder',
#  'primary',
#  'in',
#  'tickets',
#  'dick',
#  'amending',
#  'incomparable',
#  'startled',
#  'installed',
#  'lawford',
#  "capital's",
#  '5-day',
#  'papers',
#  'forces',
#  "mccloy's",
#  'homeowners',
#  'idols',
#  'ballets',
#  'self',
#  'bryson',
#  'teamsters',
#  'picketed',
#  'dignity',
#  'rickards',
#  'water',
#  'note',
#  'richard',
#  'peoples',
#  'maynor',
#  '1919',
#  'e.',
#  'treadwell',
#  'perturbed',
#  'tripled',
#  'headmaster',
#  'glamor',
#  'mustang',
#  'stalemate',
#  'coal',
#  '175',
#  'strayed',
#  'labor-management',
#  'tenure',
#  'reconvention',
#  'trends',
#  'strenuous',
#  'stupidity',
#  '1899',
#  'every',
#  'competition',
#  'affirmation',
#  'physician',
#  'beaming',
#  'ringside',
#  "warehouseman's",
#  'chiang',
#  '1922',
#  'resort',
#  'stopovers',
#  'nodded',
#  'stimulant',
#  'bertorelli',
#  'frustrated',
#  'shade',
#  'soviet',
#  'squarely',
#  'outdoors',
#  '4-1/2%',
#  'judge',
#  'sharing',
#  'questions',
#  'pickers',
#  'forcing',
#  'revenuers',
#  'moments',
#  'paycheck',
#  'improve',
#  'double',
#  'schley',
#  'stanley',
#  'waggin',
#  'heinkel',
#  'enthralled',
#  'stevedore',
#  'hill',
#  'congressional',
#  'banjo',
#  'jet',
#  'embezzlement',
#  'wash',
#  'january',
#  'probate',
#  'shoes',
#  'brownings',
#  'were',
#  'c',
#  'presidential',
#  '$37',
#  'franchise',
#  'signals',
#  "students'",
#  'dish',
#  'unmeritorious',
#  'darrow',
#  'propelling',
#  'oppose',
#  'forecasts',
#  'profili',
#  'describing',
#  'efficient',
#  'further',
#  'dazzler',
#  '69',
#  'noel',
#  'pleasant',
#  'pertained',
#  'completion',
#  'main',
#  'gradually',
#  'protect',
#  '$18.2',
#  'blumenthal',
#  'dennis',
#  'walnut',
#  'g.',
#  '13-5',
#  'kimmell',
#  'democratic-endorsed',
#  'marine',
#  'france',
#  'packs',
#  'greater',
#  'trimmed',
#  'fierce',
#  'kern',
#  'spraying',
#  'ultimate',
#  '5835',
#  'experiencing',
#  'pictured',
#  'numerous',
#  'administered',
#  '1960s',
#  'distinguished',
#  '1910-14',
#  'loop',
#  'does',
#  'author',
#  'gas',
#  "coach's",
#  'grayson',
#  'stitch',
#  'authorize',
#  '200',
#  'glass',
#  'relatively',
#  'rayburn',
#  '1959',
#  'banned',
#  'lettered',
#  'consultant',
#  'genevieve',
#  'hired',
#  'eustis',
#  'east',
#  'confrontation',
#  'tex.',
#  'missed',
#  '2269',
#  '1940',
#  'opposite',
#  "contractor's",
#  'posed',
#  'adair',
#  'braves',
#  'appliances',
#  'towering',
#  'derived',
#  'here',
#  'nuns',
#  'imagines',
#  'substance',
#  'uniformed',
#  '65%',
#  'stages',
#  'deteriorating',
#  '121',
#  'education',
#  'therefore',
#  'crews',
#  '.',
#  'during',
#  'infant',
#  'appreciation',
#  'developments',
#  'deal',
#  'arm',
#  'brother-in-law',
#  'planners',
#  'smallwood',
#  'workers',
#  'foreign',
#  'ex-mrs.',
#  '798',
#  'worsens',
#  'distinctly',
#  'heralded',
#  'lasted',
#  'publicity',
#  'compassionate',
#  'suggested',
#  'larceny',
#  'bounds',
#  'provides',
#  'scrambled',
#  'd.c.',
#  'dead',
#  'kanin',
#  'fourth-down',
#  '$100,000',
#  'seize',
#  'buchheister',
#  'nick',
#  'ponies',
#  'dec.',
#  'south',
#  "junior's",
#  'dealing',
#  "engineers'",
#  'carson',
#  'sandra',
#  'ratification',
#  'miscount',
#  'island',
#  'staffed',
#  'hearty',
#  'dependence',
#  '1688',
#  'process',
#  'replies',
#  'dominated',
#  'beaten',
#  'greenwood',
#  'upheld',
#  "fardulli's",
#  'flag-stick',
#  'tech.',
#  'threats',
#  '1952',
#  'lumumba',
#  'underdeveloped',
#  'particular',
#  'sculptured',
#  'recommendations',
#  'puddingstone',
#  'low-flying',
#  'erred',
#  'identically',
#  'spending',
#  'stoppages',
#  'pad',
#  'acclimatized',
#  'culpas',
#  'hard',
#  'crypt',
#  'rapped',
#  'statistical',
#  'scherer',
#  'granular-type',
#  'treated',
#  'relations',
#  'orleans',
#  'seconds',
#  'succeeding',
#  'nuttall',
#  'cooke',
#  'bootle',
#  'goods',
#  'bludgeon',
#  'egerton',
#  'downtown',
#  'urban',
#  'aims',
#  'salem',
#  'squabbles',
#  'nations',
#  "manufacturers'",
#  'scene',
#  'fuels',
#  'lyle',
#  'practices',
#  'paid-for',
#  'okla.',
#  'loading',
#  'upi',
#  '$1,600',
#  'landscaped',
#  'ligget',
#  'big-league',
#  'holabird',
#  'adult',
#  'critic',
#  'passed',
#  'closer',
#  'dorsey',
#  'slackening',
#  'vernor',
#  'you',
#  'went',
#  'anderlini',
#  'struggles',
#  'zinman',
#  'competitive',
#  'there',
#  'yardstick',
#  'establishing',
#  'recalls',
#  'opportunity',
#  "chronicle's",
#  'moffett',
#  'canvassed',
#  'surprise',
#  '$457,000',
#  '3-10',
#  'socks',
#  'joints',
#  'inlaid',
#  'stern',
#  'balenciaga',
#  'gave',
#  '1957',
#  'collided',
#  'trigg',
#  'envision',
#  'gesture',
#  "republicans'",
#  'underwriting',
#  'lull',
#  'chance',
#  'swearing',
#  'okinawa',
#  'encouraging',
#  'capabilities',
#  'aquinas',
#  'gaynor',
#  'underwater',
#  'exports',
#  'profit',
#  'safety',
#  'unquestionably',
#  'pointed',
#  'literature',
#  'liberals',
#  'stoll',
#  'ghastly',
#  'undergone',
#  'poured',
#  'staggered',
#  '$1,500,000',
#  'deemed',
#  'vietnamese',
#  'madame',
#  'unlike',
#  'hits',
#  'ninety-nine',
#  'accommodated',
#  'sponsoring',
#  'opening',
#  'extend',
#  'lavishly',
#  'nowhere',
#  'risk',
#  'guatemala',
#  'accurate',
#  'drive-in',
#  'idealist',
#  'u.s.',
#  'power',
#  'switching',
#  'slaughter',
#  'mazeroski',
#  'savannah',
#  'employ',
#  'handicapped',
#  'pastime',
#  'latch',
#  'ideal',
#  'three-day',
#  'within',
#  'impossibly',
#  'wheat',
#  'fastest',
#  'run',
#  '1937',
#  'big',
#  'mcn.',
#  'violating',
#  '237%',
#  'bedrooms',
#  'electricity',
#  'dorenzo',
#  'farrell',
#  'discharge',
#  'appealing',
#  'onetime',
#  'niece',
#  'swearing-in',
#  'crossing',
#  'courbet',
#  'remark',
#  '20,000',
#  "nation's",
#  'music',
#  'grace',
#  '187.5',
#  'parker',
#  'unhappy',
#  'retirements',
#  'knows',
#  '49ers',
#  'grandparents',
#  'recounting',
#  '$253,355,000',
#  'drizzly',
#  "palmer's",
#  'been',
#  'pace',
#  'better',
#  'criminals',
#  'oliver',
#  '$80,738',
#  'collection',
#  'smashed',
#  'arnold',
#  'hardy',
#  'wear',
#  'expensive',
#  'religious',
#  'requirement',
#  'voted',
#  'preview',
#  'instrument',
#  'underprivileged',
#  'violent',
#  'heroin',
#  'underlying',
#  'ham',
#  'disable',
#  'candor',
#  'dist.',
#  'esprit',
#  'visits',
#  'r.l.',
#  'sledding',
#  'sugar',
#  'side',
#  'kroger',
#  'philosopher',
#  'three-hour',
#  'typewriters',
#  'advances',
#  'brigantine',
#  'forms',
#  'researchers',
#  'well-armed',
#  'representations',
#  'fatal',
#  'faculty',
#  '$8.50',
#  'divided',
#  'flowed',
#  'pile',
#  'washed-out',
#  'moves',
#  'parks',
#  'tractor',
#  'toughness',
#  'forthcoming',
#  'almost',
#  'repertory',
#  'planner',
#  'send',
#  'motto',
#  'erection',
#  'crime',
#  'crackpots',
#  '3-inch',
#  'p.m.',
#  'vitally',
#  'craig',
#  'penalized',
#  'spokesman',
#  'forty-year',
#  'sixth-sense',
#  'cincinnati',
#  'givers',
#  'couve',
#  'plan',
#  'staffs',
#  'flower',
#  'laotian',
#  'dewey',
#  'real',
#  'bester',
#  'bean',
#  'nearby',
#  'over-night',
#  'acid',
#  'sparkle',
#  'master',
#  'southwest',
#  'three-building',
#  'adcock',
#  "league's",
#  '4:18',
#  'georgia-pacific',
#  'bring',
#  'a.a.u.',
#  'disposal',
#  'saute',
#  'mink',
#  'book-selection',
#  'possessive',
#  '2.5%',
#  'reiterate',
#  'lived',
#  'release',
#  'high-density',
#  'shaw',
#  'one-week-old',
#  'talents',
#  'rackmil',
#  'complaining',
#  'surgery',
#  'hostages',
#  'switch',
#  'go',
#  'unchecked',
#  'allison',
#  'thoroughfare',
#  'ten-hour',
#  '361',
#  'thru',
#  'us',
#  'capitalist',
#  'oxford',
#  'modernized',
#  'traveler',
#  'truman',
#  'overpowered',
#  'smythe',
#  'commerce',
#  'edwards',
#  'indictment',
#  'orchids',
#  'uncas',
#  'firing',
#  'clifford',
#  "a's",
#  'severly',
#  'stark',
#  'votes',
#  'willingness',
#  'trouble',
#  'eddie',
#  'walkout',
#  'raymondville',
#  'scarcely',
#  'working',
#  'factor',
#  'warned',
#  'negotiations',
#  'bernie',
#  'exhibited',
#  'walter',
#  'lace',
#  'dignitaries',
#  'president-elect',
#  'tolls',
#  'hollander',
#  'crucified',
#  'affect',
#  'chico',
#  'elements',
#  'majorities',
#  'pressed-paper',
#  'politely',
#  'detonation',
#  'fergeson',
#  "mills's",
#  'fouled',
#  'bernardine',
#  '100%',
#  'geography',
#  'loaded',
#  'buck',
#  'embedded',
#  'raising',
#  'crashed',
#  'climbed',
#  'contracts',
#  'suit',
#  'arkansas',
#  'wissahickon',
#  '1865',
#  'me',
#  'wholesale',
#  'fabrics',
#  '55',
#  'studying',
#  'vieth',
#  '5847',
#  'tense',
#  'alba',
#  'leary',
#  'undoubtedly',
#  'high-school',
#  'socialized',
#  'join',
#  'industrial',
#  'undertakes',
#  'deposit',
#  'southwestern',
#  'pro-western',
#  'andrew',
#  'communications',
#  'whee',
#  'relationships',
#  'very',
#  'bachelor',
#  'globe-democrat',
#  'crucial',
#  'conversation',
#  'consulate',
#  'only',
#  'we',
#  'carruthers',
#  'bed-time',
#  'technicians',
#  'vehicle',
#  'due',
#  'prominently',
#  'unique',
#  'initiating',
#  'object',
#  '33-man',
#  'skid',
#  'sybert',
#  'tareytown',
#  'priced',
#  'champion',
#  'waters',
#  'gain',
#  'wise',
#  'mayor-nominate',
#  'comprise',
#  'hubert',
#  'jolly',
#  '300,000',
#  'robertsons',
#  'angeles',
#  'companionship',
#  'contact',
#  'sylvania',
#  'hills',
#  'electrical',
#  'plenty',
#  'southerners',
#  'cd',
#  'cyclical',
#  'instrumentals',
#  'notably',
#  'dental',
#  'referendum',
#  'recipients',
#  'superior',
#  "chicago's",
#  'fireside',
#  'churchmen',
#  'princess',
#  'marked',
#  'gals',
#  'joey',
#  'abuse',
#  'gotham',
#  'purchase',
#  'border',
#  'pitcher',
#  'idol',
#  'danger',
#  'woodcarver',
#  'destroyer',
#  'hudson',
#  'governs',
#  'solicitor',
#  'skiddy',
#  'groove',
#  'conversion',
#  'percentage',
#  'slower',
#  'sees',
#  'friends',
#  'jerry',
#  '380-foot',
#  'awareness',
#  'slow',
#  'revealed',
#  'respond',
#  'airport',
#  '87th',
#  'prix',
#  'inferior',
#  'sportswriter',
#  '50,000,000',
#  "monday's",
#  '1213',
#  'tractors',
#  '3-month',
#  'attempt',
#  'congolese',
#  'bum',
#  'bexar',
#  'ineffectual',
#  'equipment',
#  'computers',
#  'convicted',
#  'butlers',
#  'frankie',
#  'fulton',
#  'foreman',
#  'fourteen-nation',
#  'scholar',
#  'hong',
#  'tosses',
#  'bit',
#  'harry',
#  'verify',
#  'characteristic',
#  'led',
#  'transit',
#  'simultaneous',
#  'eve',
#  'rates',
#  'micro-microcurie',
#  'miniver',
#  'fairy',
#  'pastors',
#  'resident',
#  'realistic',
#  '3300',
#  'compacts',
#  'chardon',
#  'jean',
#  'regents',
#  'playable',
#  "women's",
#  '$37,500',
#  'peaks',
#  "rickey's",
#  'positive',
#  'yuri',
#  '$28,700,000',
#  'judges',
#  'retrenching',
#  'adventures',
#  'plague',
#  'costumes',
#  '(',
#  'wegener',
#  'insects',
#  'hyde',
#  'abel',
#  'knight',
#  'unemployment',
#  'vroman',
#  'neveh',
#  'oceania',
#  'effectively',
#  "speaker's",
#  'begins',
#  '20%',
#  'ladies',
#  'agents',
#  '65',
#  'honorary',
#  'absorb',
#  'starter',
#  'cal.',
#  'swipe',
#  'engage',
#  'publicly',
#  'communism',
#  'budgets',
#  'scoring',
#  'neighbor',
#  'sokol',
#  'enforcement',
#  'warden',
#  'newport',
#  'vicinity',
#  'constitution',
#  'veteran',
#  'something',
#  'pun',
#  'lisle',
#  "mechanic's",
#  'tuesday',
#  "nato's",
#  'enabled',
#  'mentioned',
#  'houghton',
#  'blanche',
#  'privilege',
#  'path',
#  'stockholders',
#  'eventual',
#  'virtues',
#  'interference',
#  'courageous',
#  'parents',
#  'bloodstream',
#  'sleeps',
#  'licensing',
#  'imbroglio',
#  'emerges',
#  'idealism',
#  'pursued',
#  "glimco's",
#  'german',
#  '7',
#  'reputedly',
#  '59',
#  "mayor's",
#  'suffered',
#  'chapelles',
#  'church-state',
#  'amicable',
#  'holiday',
#  'ex-singer',
#  'executive',
#  'so-far',
#  'dimaggio',
#  'hayward',
#  'coordination',
#  ...]

# %%
jobs = torch.LongTensor([word2index['jobs']])
jobs
# Out:
# tensor([7651])

# %%
jobs_embed_c = model.embedding_center(jobs)
jobs_embed_o = model.embedding_outside(jobs)
jobs_embed   = (jobs_embed_c + jobs_embed_o) / 2
jobs_embed
# Out:
# tensor([[-0.6840,  0.4285, -0.1019,  0.5842, -0.2463,  0.5857,  0.2184,  0.7996,
#          -0.3702, -1.2857]], grad_fn=<DivBackward0>)

# %%
jobs_embed_o
# Out:
# tensor([[-1.6684, -0.4668,  0.1689, -0.4969, -0.1411,  0.1998,  0.9985,  0.4364,
#          -0.8788, -1.4734]], grad_fn=<EmbeddingBackward0>)

# %%
def get_embed(word):
    try:
        index = word2index[word]
    except:
        index = word2index['<UNK>']
        
    word = torch.LongTensor([word2index[word]])
    
    embed_c = model.embedding_center(word)
    embed_o = model.embedding_outside(word)
    embed   = (embed_c + embed_o) / 2
    
    return embed[0][0].item(), embed[0][1].item()

# %%
get_embed('vacancy')
# Out:
# (1.1550911664962769, 0.008116543292999268)

# %%
get_embed('death')
# Out:
# (-0.4139266908168793, 0.49589985609054565)

# %%
get_embed('architecture')
# Out:
# (-0.8513450622558594, 0.2619168758392334)

# %%
get_embed('jobs')
# Out:
# (-0.6839858889579773, 0.42847001552581787)

# %%
# plt.figure(figsize=(6, 3))
# for i, word in enumerate(vocabs):
#     x, y = get_embed(word)
#     plt.scatter(x, y)
#     plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points')
# plt.show()

# %% [markdown]
# ## 7. Cosine similarity

# %%
jobs = get_embed('jobs')
jobs
# Out:
# (-0.6839858889579773, 0.42847001552581787)

# %%
vacancy = get_embed('vacancy')
vacancy
# Out:
# (1.1550911664962769, 0.008116543292999268)

# %%
death = get_embed('death')
death
# Out:
# (-0.4139266908168793, 0.49589985609054565)

# %%
#more formally is to divide by its norm
def cosine_similarity(A, B):
    dot_product = np.dot(A, B)
    norm_a = np.linalg.norm(A)
    norm_b = np.linalg.norm(B)
    similarity = dot_product / (norm_a * norm_b)
    return similarity

print(cosine_similarity(np.array(jobs), np.array(vacancy)))
print(cosine_similarity(np.array(jobs), np.array(death)))
# Out:
# -0.8437016633192334
# 0.9506024379657818

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))


# Step 1: build final embedding matrix
W = (model.embedding_center.weight.detach().cpu().numpy() +
     model.embedding_outside.weight.detach().cpu().numpy()) / 2

# Normalize embeddings for fast cosine similarity
W_norm = W / np.linalg.norm(W, axis=1, keepdims=True)



def get_vector(word):
    if word not in word2index:
        return None
    return W_norm[word2index[word]]

# %%
print(W.shape)
print(get_vector("jobs"))
print(len(get_vector("jobs")))
# Out:
# (13113, 10)
# [-0.34706408  0.21741173 -0.05169694  0.29644683 -0.12497501  0.29719865
#   0.11080109  0.40571707 -0.18783988 -0.6523899 ]
# 10

# %%
index2word = {idx: word for word, idx in word2index.items()}
def predict_analogy(a, b, c, W_norm, word2index, index2word):
    if a not in word2index or b not in word2index or c not in word2index:
        return None

    va = W_norm[word2index[a]]
    vb = W_norm[word2index[b]]
    vc = W_norm[word2index[c]]

    # Vector arithmetic: b - a + c
    target = vb - va + vc
    target = target / np.linalg.norm(target)

    # Cosine similarity with ALL words at once
    similarities = np.dot(W_norm, target)

    # Exclude input words
    for w in (a, b, c):
        similarities[word2index[w]] = -1

    best_index = np.argmax(similarities)
    return index2word[best_index]

# %%
predict_analogy("jobs", "vacancy", "death", W, word2index, index2word)
# Out:
# 'holds'

# %%
def evaluate_analogies(file_path, W_norm, word2index, index2word):
    total = 0
    correct = 0

    with open(file_path, "r") as f:
        for line in f:
            words = line.strip().split()
            if len(words) != 4:
                continue

            a, b, c, d = words
            prediction = predict_analogy(
                a, b, c, W_norm, word2index, index2word
            )

            if prediction is None:
                continue

            total += 1
            if prediction == d:
                correct += 1

    accuracy = correct / total if total > 0 else 0
    return accuracy, correct, total

# %%
semantic_acc, sem_correct, sem_total = evaluate_analogies(
    "country-capital.txt",
    W,
    word2index,
    index2word
)

# %%
syntactic_acc, syn_correct, syn_total = evaluate_analogies(
    "past-tense.txt",
    W,
    word2index,
    index2word
)

print(f"Semantic accuracy (capital-common-countries): {semantic_acc:.4f} ({sem_correct}/{sem_total})")
print(f"Syntactic accuracy (past-tense): {syntactic_acc:.4f} ({syn_correct}/{syn_total})")
# Out:
# Semantic accuracy (capital-common-countries): 0.0000 (0/0)
# Syntactic accuracy (past-tense): 0.0000 (0/648)

# %%
import pandas as pd

similarity_df = pd.read_csv("combined.csv")
similarity_df.head()
# Out:
#      Word 1    Word 2  Human (mean)
# 0      love       sex          6.77
# 1     tiger       cat          7.35
# 2     tiger     tiger         10.00
# 3      book     paper          7.46
# 4  computer  keyboard          7.62

# %%
model_scores = []
human_scores = []
skipped = 0

for _, row in similarity_df.iterrows():
    w1 = row["Word 1"]
    w2 = row["Word 2"]
    human_score = row["Human (mean)"]

    if w1 not in word2index or w2 not in word2index:
        skipped += 1
        continue

    v1 = W_norm[word2index[w1]]
    v2 = W_norm[word2index[w2]]

    model_sim = np.dot(v1, v2)  # cosine similarity

    model_scores.append(model_sim)
    human_scores.append(human_score)

print(f"Used pairs: {len(model_scores)}")
print(f"Skipped OOV pairs: {skipped}")
# Out:
# Used pairs: 197
# Skipped OOV pairs: 156

# %%
from scipy.stats import spearmanr

correlation, p_value = spearmanr(model_scores, human_scores)

print(f"Spearman correlation: {correlation:.4f}")
print(f"P-value: {p_value:.4e}")
# Out:
# Spearman correlation: 0.0276
# P-value: 7.0055e-01

# %%
print("Example comparisons:")
for i in range(5):
    print(
        similarity_df.iloc[i, 0],
        similarity_df.iloc[i, 1],
        "Human:", human_scores[i],
        "Model:", round(model_scores[i], 3)
    )
# Out:
# Example comparisons:
# love sex Human: 6.77 Model: -0.226
# tiger cat Human: 7.46 Model: 0.095
# tiger tiger Human: 5.77 Model: 0.166
# book paper Human: 6.31 Model: -0.799
# computer keyboard Human: 7.5 Model: -0.059

# %% [markdown]
# ## Summary: Word2Vec with Negative Sampling
#
# This notebook implements the **Word2Vec (Skip-gram)** model using **Negative Sampling** to efficiently learn word embeddings from the NLTK Reuters corpus.
#
# ### Key Components:
# * **Data Preprocessing**:
#     * Loaded the `reuters` dataset and performed tokenization (lowercase, alphabetic filtering).
#     * Implemented numeralization and vocabulary building to map tokens to unique integers.
# * **Training Strategy**:
#     * Utilized **Negative Sampling** to optimize the training process by updating only a small percentage of weights for each iteration rather than the entire vocabulary.
#     * Defined a context window for generating positive pairs and sampled "noise" words for negative pairs.
# * **Model Architecture**:
#     * Built using `torch.nn`, featuring separate embedding layers for center and context words.
# * **Evaluation**:
#     * Evaluated the learned embeddings using the **WordSim-353** dataset.
#     * Calculated **Spearman Correlation** between model-generated cosine similarities and human-assigned similarity scores.
#     * **Results**: The model demonstrates its ability to capture semantic relationships (e.g., `tiger` vs `cat`), though performance varies based on training duration and corpus size.

# %%
import json
import pickle

# Export embeddings as JSON
embeddings_dict = {
    "W": W.tolist(),
    "W_norm": W_norm.tolist(),
    "word2index": word2index,
    "index2word": {str(k): v for k, v in index2word.items()}
}

with open("output/skipgram_neg_embeddings.json", "w") as f:
    json.dump(embeddings_dict, f)

# Export corpus
with open("output/corpus.json", "w") as f:
    json.dump(corpus, f)

# Export as pickle for faster loading
with open("output/skipgram_neg_embeddings.pkl", "wb") as f:
    pickle.dump(embeddings_dict, f)

with open("output/corpus.pkl", "wb") as f:
    pickle.dump(corpus, f)

print("Embeddings and corpus exported successfully!")
print(f"Embeddings shape: {W.shape}")
print(f"Corpus size: {len(corpus)} words")
# Out:
# Embeddings and corpus exported successfully!
# Embeddings shape: (13113, 10)
# Corpus size: 100554 words
